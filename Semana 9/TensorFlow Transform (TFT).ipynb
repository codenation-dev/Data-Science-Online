# %% [markdown]
# ## Installing libraries

# %%
# !pip install tensorflow-transform
# Out:
# Collecting tensorflow-transform
#   Downloading https://files.pythonhosted.org/packages/2d/bd/8ba8c1310cd741e0b83d8a064645a55c557df5a2f6b4beb11cd3a37457ed/tensorflow-transform-0.21.2.tar.gz (241kB)
#      |████████████████████████████████| 245kB 4.8MB/s
# Requirement already satisfied: absl-py<0.9,>=0.7 in /usr/local/lib/python2.7/dist-packages (from tensorflow-transform) (0.7.1)
# Collecting apache-beam[gcp]<3,>=2.17
#   Downloading https://files.pythonhosted.org/packages/33/02/539f40be7b4d2ba338890cc7ca18fb55617199834070856a09b47e40cabe/apache_beam-2.20.0-cp27-cp27mu-manylinux1_x86_64.whl (3.4MB)
#      |████████████████████████████████| 3.4MB 15.1MB/s
# Requirement already satisfied: numpy<2,>=1.16 in /usr/local/lib/python2.7/dist-packages (from tensorflow-transform) (1.16.4)
# Requirement already satisfied: protobuf<4,>=3.7 in /usr/local/lib/python2.7/dist-packages (from tensorflow-transform) (3.8.0)
# Requirement already satisfied: pydot<2,>=1.2 in /usr/local/lib/python2.7/dist-packages (from tensorflow-transform) (1.3.0)
# Requirement already satisfied: six<2,>=1.12 in /usr/local/lib/python2.7/dist-packages (from tensorflow-transform) (1.12.0)
# Collecting tensorflow-metadata<0.22,>=0.21
#   Downloading https://files.pythonhosted.org/packages/57/12/213dc5982e45283591ee0cb535b08ff603200ba84643bbea0aaa2109ed7c/tensorflow_metadata-0.21.2-py2.py3-none-any.whl
# Requirement already satisfied: tensorflow<2.2,>=1.15 in /usr/local/lib/python2.7/dist-packages (from tensorflow-transform) (2.1.0)
# Collecting tfx-bsl<0.22,>=0.21.3
#   Downloading https://files.pythonhosted.org/packages/e6/a8/45fc7c95154caa82f15c047d1312f9a8e9e29392f9137c22f972359996e8/tfx_bsl-0.21.4-cp27-cp27mu-manylinux2010_x86_64.whl (1.9MB)
#      |████████████████████████████████| 1.9MB 59.0MB/s
# Requirement already satisfied: enum34; python_version < "3.4" in /usr/local/lib/python2.7/dist-packages (from absl-py<0.9,>=0.7->tensorflow-transform) (1.1.6)
# Collecting pyarrow<0.17.0,>=0.15.1; python_version >= "3.0" or platform_system != "Windows"
#   Downloading https://files.pythonhosted.org/packages/21/c7/20a5dab16391f7a31e1daf02b639c11210378a92ce66dcf07f529a491951/pyarrow-0.16.0-cp27-cp27mu-manylinux2010_x86_64.whl (20.5MB)
#      |████████████████████████████████| 20.5MB 1.4MB/s
# Collecting fastavro<0.22,>=0.21.4
#   Downloading https://files.pythonhosted.org/packages/15/e3/5956c75f68906b119191ef30d9acff661b422cf918a29a03ee0c3ba774be/fastavro-0.21.24-cp27-cp27mu-manylinux1_x86_64.whl (1.0MB)
#      |████████████████████████████████| 1.0MB 54.2MB/s
# Requirement already satisfied: future<1.0.0,>=0.16.0 in /usr/local/lib/python2.7/dist-packages (from apache-beam[gcp]<3,>=2.17->tensorflow-transform) (0.16.0)
# Collecting avro<1.10.0,>=1.8.1; python_version < "3.0"
#   Downloading https://files.pythonhosted.org/packages/d7/0b/592692ed26de33f35bf596780e6adb85c47e3e58061369bbc99125b902ec/avro-1.9.2.tar.gz (49kB)
#      |████████████████████████████████| 51kB 8.6MB/s
# Requirement already satisfied: pytz>=2018.3 in /usr/local/lib/python2.7/dist-packages (from apache-beam[gcp]<3,>=2.17->tensorflow-transform) (2018.9)
# Requirement already satisfied: httplib2<=0.12.0,>=0.8 in /usr/local/lib/python2.7/dist-packages (from apache-beam[gcp]<3,>=2.17->tensorflow-transform) (0.11.3)
# Requirement already satisfied: futures<4.0.0,>=3.2.0; python_version < "3.0" in /usr/local/lib/python2.7/dist-packages (from apache-beam[gcp]<3,>=2.17->tensorflow-transform) (3.2.0)
# Requirement already satisfied: funcsigs<2,>=1.0.2; python_version < "3.0" in /usr/local/lib/python2.7/dist-packages (from apache-beam[gcp]<3,>=2.17->tensorflow-transform) (1.0.2)
# Requirement already satisfied: grpcio<2,>=1.12.1 in /usr/local/lib/python2.7/dist-packages (from apache-beam[gcp]<3,>=2.17->tensorflow-transform) (1.15.0)
# Collecting python-dateutil<3,>=2.8.0
#   Downloading https://files.pythonhosted.org/packages/d4/70/d60450c3dd48ef87586924207ae8907090de0b306af2bce5d134d78615cb/python_dateutil-2.8.1-py2.py3-none-any.whl (227kB)
#      |████████████████████████████████| 235kB 53.9MB/s
# Collecting pyvcf<0.7.0,>=0.6.8; python_version < "3.0"
#   Downloading https://files.pythonhosted.org/packages/20/b6/36bfb1760f6983788d916096193fc14c83cce512c7787c93380e09458c09/PyVCF-0.6.8.tar.gz
# Collecting typing-extensions<3.8.0,>=3.7.0
#   Downloading https://files.pythonhosted.org/packages/55/17/3f65ede2450a51ab7b8c6f9f4aa1ba07cddd980422e2409ea5d68ccdf38d/typing_extensions-3.7.4.2-py2-none-any.whl
# Requirement already satisfied: crcmod<2.0,>=1.7 in /usr/local/lib/python2.7/dist-packages (from apache-beam[gcp]<3,>=2.17->tensorflow-transform) (1.7)
# Collecting hdfs<3.0.0,>=2.1.0
#   Downloading https://files.pythonhosted.org/packages/82/39/2c0879b1bcfd1f6ad078eb210d09dbce21072386a3997074ee91e60ddc5a/hdfs-2.5.8.tar.gz (41kB)
#      |████████████████████████████████| 51kB 7.4MB/s
# Requirement already satisfied: typing<3.8.0,>=3.7.0; python_version < "3.5.3" in /usr/local/lib/python2.7/dist-packages (from apache-beam[gcp]<3,>=2.17->tensorflow-transform) (3.7.4)
# Requirement already satisfied: mock<3.0.0,>=1.0.1 in /usr/local/lib/python2.7/dist-packages (from apache-beam[gcp]<3,>=2.17->tensorflow-transform) (2.0.0)
# Collecting dill<0.3.2,>=0.3.1.1
#   Downloading https://files.pythonhosted.org/packages/c7/11/345f3173809cea7f1a193bfbf02403fff250a3360e0e118a1630985e547d/dill-0.3.1.1.tar.gz (151kB)
#      |████████████████████████████████| 153kB 55.4MB/s
# Requirement already satisfied: pymongo<4.0.0,>=3.8.0 in /usr/local/lib/python2.7/dist-packages (from apache-beam[gcp]<3,>=2.17->tensorflow-transform) (3.8.0)
# Collecting oauth2client<4,>=2.0.1
#   Downloading https://files.pythonhosted.org/packages/c0/7b/bc893e35d6ca46a72faa4b9eaac25c687ce60e1fbe978993fe2de1b0ff0d/oauth2client-3.0.0.tar.gz (77kB)
#      |████████████████████████████████| 81kB 12.4MB/s
# Collecting google-cloud-pubsub<1.1.0,>=0.39.0; extra == "gcp"
#   Downloading https://files.pythonhosted.org/packages/d3/91/07a82945a7396ea34debafd476724bb5fc267c292790fdf2138c693f95c5/google_cloud_pubsub-1.0.2-py2.py3-none-any.whl (118kB)
#      |████████████████████████████████| 122kB 47.7MB/s
# Collecting google-cloud-dlp<=0.13.0,>=0.12.0; extra == "gcp"
#   Downloading https://files.pythonhosted.org/packages/24/65/c74f730d5c08affdb056250e601f77c54c0f7c13dfd1c865e02f98b4e7b4/google_cloud_dlp-0.13.0-py2.py3-none-any.whl (151kB)
#      |████████████████████████████████| 153kB 63.3MB/s
# Requirement already satisfied: google-cloud-bigquery<=1.24.0,>=1.6.0; extra == "gcp" in /usr/local/lib/python2.7/dist-packages (from apache-beam[gcp]<3,>=2.17->tensorflow-transform) (1.14.0)
# Collecting proto-google-cloud-datastore-v1<=0.90.4,>=0.90.0; python_version < "3.0" and extra == "gcp"
#   Downloading https://files.pythonhosted.org/packages/2a/1f/4124f15e1132a2eeeaf616d825990bb1d395b4c2c37362654ea5cd89bb42/proto-google-cloud-datastore-v1-0.90.4.tar.gz
# Collecting google-cloud-language<2,>=1.3.0; extra == "gcp"
#   Downloading https://files.pythonhosted.org/packages/ba/b8/965a97ba60287910d342623da1da615254bded3e0965728cf7fc6339b7c8/google_cloud_language-1.3.0-py2.py3-none-any.whl (83kB)
#      |████████████████████████████████| 92kB 12.7MB/s
# Collecting google-cloud-videointelligence<1.14.0,>=1.8.0; extra == "gcp"
#   Downloading https://files.pythonhosted.org/packages/bb/bd/9945e21aace32bc45a17b65944b5cd20efb7370985d8984425831a47ca22/google_cloud_videointelligence-1.13.0-py2.py3-none-any.whl (177kB)
#      |████████████████████████████████| 184kB 48.3MB/s
# Requirement already satisfied: cachetools<4,>=3.1.0; extra == "gcp" in /usr/local/lib/python2.7/dist-packages (from apache-beam[gcp]<3,>=2.17->tensorflow-transform) (3.1.1)
# Collecting google-apitools<0.5.29,>=0.5.28; extra == "gcp"
#   Downloading https://files.pythonhosted.org/packages/07/5e/3e04cb66f5ced9267a854184bb09863d85d199646ea8480fee26b4313a00/google_apitools-0.5.28-py2-none-any.whl (134kB)
#      |████████████████████████████████| 143kB 63.2MB/s
# Collecting google-cloud-bigtable<1.1.0,>=0.31.1; extra == "gcp"
#   Downloading https://files.pythonhosted.org/packages/95/af/0ef7d097a1d5ad0c843867600e86de915e8ab8864740f49a4636cfb51af6/google_cloud_bigtable-1.0.0-py2.py3-none-any.whl (232kB)
#      |████████████████████████████████| 235kB 59.4MB/s
# Collecting grpcio-gcp<1,>=0.2.2; extra == "gcp"
#   Downloading https://files.pythonhosted.org/packages/ba/83/1f1095815be0de19102df41e250ebbd7dae97d7d14e22c18da07ed5ed9d4/grpcio_gcp-0.2.2-py2.py3-none-any.whl
# Collecting googledatastore<7.1,>=7.0.1; python_version < "3.0" and extra == "gcp"
#   Downloading https://files.pythonhosted.org/packages/3a/cf/5d90efdb2a513d5c02ba0675eefb246250b67a6ec81de610ac94d47cf1ca/googledatastore-7.0.2.tar.gz
# Requirement already satisfied: google-cloud-core<2,>=0.28.1; extra == "gcp" in /usr/local/lib/python2.7/dist-packages (from apache-beam[gcp]<3,>=2.17->tensorflow-transform) (1.0.2)
# Collecting google-cloud-vision<0.43.0,>=0.38.0; extra == "gcp"
#   Downloading https://files.pythonhosted.org/packages/eb/23/6d5a728333ce568fb484d0d7edd0b7c04b16cf6325af31d957eb51ed077d/google_cloud_vision-0.42.0-py2.py3-none-any.whl (435kB)
#      |████████████████████████████████| 440kB 51.4MB/s
# Collecting google-cloud-datastore<1.8.0,>=1.7.1; extra == "gcp"
#   Downloading https://files.pythonhosted.org/packages/d0/aa/29cbcf8cf7d08ce2d55b9dce858f7c632b434cb6451bed17cb4275804217/google_cloud_datastore-1.7.4-py2.py3-none-any.whl (82kB)
#      |████████████████████████████████| 92kB 12.0MB/s
# Collecting google-cloud-spanner<1.14.0,>=1.13.0; extra == "gcp"
#   Downloading https://files.pythonhosted.org/packages/9e/39/c5e470bf59ce15716490bea1945e2c03b4f08f2153285f19dc6f9337b9e9/google_cloud_spanner-1.13.0-py2.py3-none-any.whl (212kB)
#      |████████████████████████████████| 215kB 59.0MB/s
# Requirement already satisfied: setuptools in /usr/local/lib/python2.7/dist-packages (from protobuf<4,>=3.7->tensorflow-transform) (44.1.0)
# Requirement already satisfied: pyparsing>=2.1.4 in /usr/local/lib/python2.7/dist-packages (from pydot<2,>=1.2->tensorflow-transform) (2.4.0)
# Requirement already satisfied: googleapis-common-protos in /usr/local/lib/python2.7/dist-packages (from tensorflow-metadata<0.22,>=0.21->tensorflow-transform) (1.6.0)
# Requirement already satisfied: gast==0.2.2 in /usr/local/lib/python2.7/dist-packages (from tensorflow<2.2,>=1.15->tensorflow-transform) (0.2.2)
# Requirement already satisfied: scipy==1.2.2; python_version < "3" in /usr/local/lib/python2.7/dist-packages (from tensorflow<2.2,>=1.15->tensorflow-transform) (1.2.2)
# Requirement already satisfied: wheel; python_version < "3" in /usr/local/lib/python2.7/dist-packages (from tensorflow<2.2,>=1.15->tensorflow-transform) (0.34.2)
# Requirement already satisfied: wrapt>=1.11.1 in /usr/local/lib/python2.7/dist-packages (from tensorflow<2.2,>=1.15->tensorflow-transform) (1.11.2)
# Requirement already satisfied: keras-preprocessing>=1.1.0 in /usr/local/lib/python2.7/dist-packages (from tensorflow<2.2,>=1.15->tensorflow-transform) (1.1.0)
# Requirement already satisfied: backports.weakref>=1.0rc1; python_version < "3.4" in /usr/local/lib/python2.7/dist-packages (from tensorflow<2.2,>=1.15->tensorflow-transform) (1.0.post1)
# Collecting tensorflow-estimator<2.2.0,>=2.1.0rc0
#   Downloading https://files.pythonhosted.org/packages/18/90/b77c328a1304437ab1310b463e533fa7689f4bfc41549593056d812fab8e/tensorflow_estimator-2.1.0-py2.py3-none-any.whl (448kB)
#      |████████████████████████████████| 450kB 52.4MB/s
# Requirement already satisfied: keras-applications>=1.0.8 in /usr/local/lib/python2.7/dist-packages (from tensorflow<2.2,>=1.15->tensorflow-transform) (1.0.8)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python2.7/dist-packages (from tensorflow<2.2,>=1.15->tensorflow-transform) (1.1.0)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python2.7/dist-packages (from tensorflow<2.2,>=1.15->tensorflow-transform) (2.3.2)
# Requirement already satisfied: functools32>=3.2.3; python_version < "3" in /usr/local/lib/python2.7/dist-packages (from tensorflow<2.2,>=1.15->tensorflow-transform) (3.2.3.post2)
# Requirement already satisfied: tensorboard<2.2.0,>=2.1.0 in /usr/local/lib/python2.7/dist-packages (from tensorflow<2.2,>=1.15->tensorflow-transform) (2.1.0)
# Requirement already satisfied: google-pasta>=0.1.6 in /usr/local/lib/python2.7/dist-packages (from tensorflow<2.2,>=1.15->tensorflow-transform) (0.1.7)
# Requirement already satisfied: astor>=0.6.0 in /usr/local/lib/python2.7/dist-packages (from tensorflow<2.2,>=1.15->tensorflow-transform) (0.8.0)
# Collecting google-api-python-client<2,>=1.7.11
#   Downloading https://files.pythonhosted.org/packages/bb/7c/39028024ad733d0a6b0d5a4a5715c675f6940b7441c356336d0e97382f06/google-api-python-client-1.8.3.tar.gz (141kB)
#      |████████████████████████████████| 143kB 55.4MB/s
# Collecting tensorflow-serving-api<3,>=1.15
#   Downloading https://files.pythonhosted.org/packages/6d/0b/be364dc6271a633629174fc02d36b2837cc802250d6a0afd96f8e7f2fae6/tensorflow_serving_api-2.1.0-py2.py3-none-any.whl
# Collecting docopt
#   Downloading https://files.pythonhosted.org/packages/a2/55/8f8cab2afd404cf578136ef2cc5dfb50baa1761b68c9da1fb1e4eed343c9/docopt-0.6.2.tar.gz
# Requirement already satisfied: requests>=2.7.0 in /usr/local/lib/python2.7/dist-packages (from hdfs<3.0.0,>=2.1.0->apache-beam[gcp]<3,>=2.17->tensorflow-transform) (2.23.0)
# Requirement already satisfied: pbr>=0.11 in /usr/local/lib/python2.7/dist-packages (from mock<3.0.0,>=1.0.1->apache-beam[gcp]<3,>=2.17->tensorflow-transform) (5.4.0)
# Requirement already satisfied: pyasn1>=0.1.7 in /usr/local/lib/python2.7/dist-packages (from oauth2client<4,>=2.0.1->apache-beam[gcp]<3,>=2.17->tensorflow-transform) (0.4.5)
# Requirement already satisfied: pyasn1-modules>=0.0.5 in /usr/local/lib/python2.7/dist-packages (from oauth2client<4,>=2.0.1->apache-beam[gcp]<3,>=2.17->tensorflow-transform) (0.2.5)
# Requirement already satisfied: rsa>=3.1.4 in /usr/local/lib/python2.7/dist-packages (from oauth2client<4,>=2.0.1->apache-beam[gcp]<3,>=2.17->tensorflow-transform) (4.0)
# Collecting google-api-core[grpc]<2.0.0dev,>=1.14.0
#   Downloading https://files.pythonhosted.org/packages/4c/b9/c0dd70bcdf06a43d1e21f387448e7997e0ce91f10d0fbee359af4cde1571/google_api_core-1.17.0-py2.py3-none-any.whl (70kB)
#      |████████████████████████████████| 71kB 10.6MB/s
# Collecting grpc-google-iam-v1<0.13dev,>=0.12.3
#   Downloading https://files.pythonhosted.org/packages/65/19/2060c8faa325fddc09aa67af98ffcb6813f39a0ad805679fa64815362b3a/grpc-google-iam-v1-0.12.3.tar.gz
# Requirement already satisfied: google-resumable-media>=0.3.1 in /usr/local/lib/python2.7/dist-packages (from google-cloud-bigquery<=1.24.0,>=1.6.0; extra == "gcp"->apache-beam[gcp]<3,>=2.17->tensorflow-transform) (0.3.2)
# Collecting fasteners>=0.14
#   Downloading https://files.pythonhosted.org/packages/18/bd/55eb2d6397b9c0e263af9d091ebdb756b15756029b3cededf6461481bc63/fasteners-0.15-py2.py3-none-any.whl
# Requirement already satisfied: h5py in /usr/local/lib/python2.7/dist-packages (from keras-applications>=1.0.8->tensorflow<2.2,>=1.15->tensorflow-transform) (2.8.0)
# Collecting google-auth-oauthlib<0.5,>=0.4.1
#   Downloading https://files.pythonhosted.org/packages/7b/b8/88def36e74bee9fce511c9519571f4e485e890093ab7442284f4ffaef60b/google_auth_oauthlib-0.4.1-py2.py3-none-any.whl
# Requirement already satisfied: werkzeug>=0.11.15 in /usr/local/lib/python2.7/dist-packages (from tensorboard<2.2.0,>=2.1.0->tensorflow<2.2,>=1.15->tensorflow-transform) (0.15.5)
# Requirement already satisfied: google-auth<2,>=1.6.3 in /usr/local/lib/python2.7/dist-packages (from tensorboard<2.2.0,>=2.1.0->tensorflow<2.2,>=1.15->tensorflow-transform) (1.7.2)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python2.7/dist-packages (from tensorboard<2.2.0,>=2.1.0->tensorflow<2.2,>=1.15->tensorflow-transform) (3.1.1)
# Requirement already satisfied: google-auth-httplib2>=0.0.3 in /usr/local/lib/python2.7/dist-packages (from google-api-python-client<2,>=1.7.11->tfx-bsl<0.22,>=0.21.3->tensorflow-transform) (0.0.3)
# Requirement already satisfied: uritemplate<4dev,>=3.0.0 in /usr/local/lib/python2.7/dist-packages (from google-api-python-client<2,>=1.7.11->tfx-bsl<0.22,>=0.21.3->tensorflow-transform) (3.0.0)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python2.7/dist-packages (from requests>=2.7.0->hdfs<3.0.0,>=2.1.0->apache-beam[gcp]<3,>=2.17->tensorflow-transform) (1.24.3)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python2.7/dist-packages (from requests>=2.7.0->hdfs<3.0.0,>=2.1.0->apache-beam[gcp]<3,>=2.17->tensorflow-transform) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python2.7/dist-packages (from requests>=2.7.0->hdfs<3.0.0,>=2.1.0->apache-beam[gcp]<3,>=2.17->tensorflow-transform) (2019.6.16)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python2.7/dist-packages (from requests>=2.7.0->hdfs<3.0.0,>=2.1.0->apache-beam[gcp]<3,>=2.17->tensorflow-transform) (2.8)
# Collecting monotonic>=0.1
#   Downloading https://files.pythonhosted.org/packages/ac/aa/063eca6a416f397bd99552c534c6d11d57f58f2e94c14780f3bbf818c4cf/monotonic-1.5-py2.py3-none-any.whl
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python2.7/dist-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.2.0,>=2.1.0->tensorflow<2.2,>=1.15->tensorflow-transform) (1.2.0)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python2.7/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.2.0,>=2.1.0->tensorflow<2.2,>=1.15->tensorflow-transform) (3.0.2)
# Building wheels for collected packages: tensorflow-transform, avro, pyvcf, hdfs, dill, oauth2client, proto-google-cloud-datastore-v1, googledatastore, google-api-python-client, docopt, grpc-google-iam-v1
#   Building wheel for tensorflow-transform (setup.py) ... done
#   Created wheel for tensorflow-transform: filename=tensorflow_transform-0.21.2-cp27-none-any.whl size=301095 sha256=82c0253d8fc5e56e1da2f4a0872bc172ef822e377bfe186d5963434e11deb521
#   Stored in directory: /root/.cache/pip/wheels/0e/fa/f9/b167f10a3392a6d90659bb821c570255458f83ad5a4a321712
#   Building wheel for avro (setup.py) ... done
#   Created wheel for avro: filename=avro-1.9.2-cp27-none-any.whl size=41686 sha256=bb6ceb4610d41468faf8bf5c8623748a61f1606b945c3106d91f82ef7e49b2fc
#   Stored in directory: /root/.cache/pip/wheels/51/14/c1/d4e383d261ced6c549ea2d072cc3a3955744948d9b0d2698f6
#   Building wheel for pyvcf (setup.py) ... done
#   Created wheel for pyvcf: filename=PyVCF-0.6.8-cp27-cp27mu-linux_x86_64.whl size=80307 sha256=ff30d868efdddbd3680cb493d2afd2c2b9cd12dc4751766fd034310eef96de8e
#   Stored in directory: /root/.cache/pip/wheels/81/91/41/3272543c0b9c61da9c525f24ee35bae6fe8f60d4858c66805d
#   Building wheel for hdfs (setup.py) ... done
#   Created wheel for hdfs: filename=hdfs-2.5.8-cp27-none-any.whl size=33213 sha256=7b1e135ff23c10b81461865ac80e8632bded8e54abc76158746313ef4179559f
#   Stored in directory: /root/.cache/pip/wheels/fe/a7/05/23e3699975fc20f8a30e00ac1e515ab8c61168e982abe4ce70
#   Building wheel for dill (setup.py) ... done
#   Created wheel for dill: filename=dill-0.3.1.1-cp27-none-any.whl size=78533 sha256=2700bb1a8dba12809006708f3ca3edca4a2993c3107fff7790ef7df7623f9fc7
#   Stored in directory: /root/.cache/pip/wheels/59/b1/91/f02e76c732915c4015ab4010f3015469866c1eb9b14058d8e7
#   Building wheel for oauth2client (setup.py) ... done
#   Created wheel for oauth2client: filename=oauth2client-3.0.0-cp27-none-any.whl size=106382 sha256=47a61e922717636629637faccef6612d67ddd0299b3c2faa0fbe5daf8d027215
#   Stored in directory: /root/.cache/pip/wheels/48/f7/87/b932f09c6335dbcf45d916937105a372ab14f353a9ca431d7d
#   Building wheel for proto-google-cloud-datastore-v1 (setup.py) ... done
#   Created wheel for proto-google-cloud-datastore-v1: filename=proto_google_cloud_datastore_v1-0.90.4-cp27-none-any.whl size=23754 sha256=7eeddaaacf606944a02a2b9a8deff9ab3c9f18bb40cad1dc40e8ad6a217ee972
#   Stored in directory: /root/.cache/pip/wheels/bd/ce/33/8b769968db3761c42c7a91d8a0dbbafc50acfa0750866c8abd
#   Building wheel for googledatastore (setup.py) ... done
#   Created wheel for googledatastore: filename=googledatastore-7.0.2-cp27-none-any.whl size=18155 sha256=4f0073a74cfa507c5aa043ea971f39d9f45127493a820971a871d4ec7c244f3b
#   Stored in directory: /root/.cache/pip/wheels/09/61/a5/7e8f4442b3c3d406ee9eb6c06e1ecbe5625f62f8cb19c08f5b
#   Building wheel for google-api-python-client (setup.py) ... done
#   Created wheel for google-api-python-client: filename=google_api_python_client-1.8.3-cp27-none-any.whl size=58914 sha256=97dafb5a34d6d33fbba24639bc597d5aaa2a5060ce3f97b7bcda24854885126a
#   Stored in directory: /root/.cache/pip/wheels/ff/d9/d5/5c685642aed9acebb10f85586a80c339d54ab921460fb09ddc
#   Building wheel for docopt (setup.py) ... done
#   Created wheel for docopt: filename=docopt-0.6.2-py2.py3-none-any.whl size=13704 sha256=7e6023461a867fc2ee0a4ba4a19564156c16d2c5296a119085da7ba5fcad27c4
#   Stored in directory: /root/.cache/pip/wheels/9b/04/dd/7daf4150b6d9b12949298737de9431a324d4b797ffd63f526e
#   Building wheel for grpc-google-iam-v1 (setup.py) ... done
#   Created wheel for grpc-google-iam-v1: filename=grpc_google_iam_v1-0.12.3-cp27-none-any.whl size=18499 sha256=dcb8a04b105e090c936d293d3e56816a7ea307e94b4bac232a5b5befa1f57469
#   Stored in directory: /root/.cache/pip/wheels/de/3a/83/77a1e18e1a8757186df834b86ce6800120ac9c79cd8ca4091b
# Successfully built tensorflow-transform avro pyvcf hdfs dill oauth2client proto-google-cloud-datastore-v1 googledatastore google-api-python-client docopt grpc-google-iam-v1
# ERROR: tfx-bsl 0.21.4 has requirement pyarrow<0.16.0,>=0.15.0, but you'll have pyarrow 0.16.0 which is incompatible.
# ERROR: fastai 0.7.0 has requirement torch<0.4, but you'll have torch 1.4.0 which is incompatible.
# ERROR: google-api-core 1.17.0 has requirement google-auth<2.0dev,>=1.14.0, but you'll have google-auth 1.7.2 which is incompatible.
# ERROR: tensorboard 2.1.0 has requirement grpcio>=1.24.3, but you'll have grpcio 1.15.0 which is incompatible.
# ERROR: google-cloud-spanner 1.13.0 has requirement google-cloud-core<2.0dev,>=1.0.3, but you'll have google-cloud-core 1.0.2 which is incompatible.
# Installing collected packages: pyarrow, fastavro, avro, python-dateutil, pyvcf, typing-extensions, docopt, hdfs, dill, oauth2client, google-api-core, grpc-google-iam-v1, google-cloud-pubsub, google-cloud-dlp, proto-google-cloud-datastore-v1, google-cloud-language, google-cloud-videointelligence, monotonic, fasteners, google-apitools, google-cloud-bigtable, grpcio-gcp, googledatastore, google-cloud-vision, google-cloud-datastore, google-cloud-spanner, apache-beam, tensorflow-metadata, google-api-python-client, tensorflow-serving-api, tfx-bsl, tensorflow-transform, tensorflow-estimator, google-auth-oauthlib
#   Found existing installation: pyarrow 0.14.0
#     Uninstalling pyarrow-0.14.0:
#       Successfully uninstalled pyarrow-0.14.0
#   Found existing installation: python-dateutil 2.5.3
#     Uninstalling python-dateutil-2.5.3:
#       Successfully uninstalled python-dateutil-2.5.3
#   Found existing installation: dill 0.3.0
#     Uninstalling dill-0.3.0:
#       Successfully uninstalled dill-0.3.0
#   Found existing installation: oauth2client 4.1.3
#     Uninstalling oauth2client-4.1.3:
#       Successfully uninstalled oauth2client-4.1.3
#   Found existing installation: google-api-core 1.13.0
#     Uninstalling google-api-core-1.13.0:
#       Successfully uninstalled google-api-core-1.13.0
#   Found existing installation: google-cloud-language 1.2.0
#     Uninstalling google-cloud-language-1.2.0:
#       Successfully uninstalled google-cloud-language-1.2.0
#   Found existing installation: google-cloud-datastore 1.8.0
#     Uninstalling google-cloud-datastore-1.8.0:
#       Successfully uninstalled google-cloud-datastore-1.8.0
#   Found existing installation: tensorflow-metadata 0.14.0
#     Uninstalling tensorflow-metadata-0.14.0:
#       Successfully uninstalled tensorflow-metadata-0.14.0
#   Found existing installation: google-api-python-client 1.7.9
#     Uninstalling google-api-python-client-1.7.9:
#       Successfully uninstalled google-api-python-client-1.7.9
#   Found existing installation: tensorflow-estimator 1.15.0
#     Uninstalling tensorflow-estimator-1.15.0:
#       Successfully uninstalled tensorflow-estimator-1.15.0
#   Found existing installation: google-auth-oauthlib 0.4.0
#     Uninstalling google-auth-oauthlib-0.4.0:
#       Successfully uninstalled google-auth-oauthlib-0.4.0
# Successfully installed apache-beam-2.20.0 avro-1.9.2 dill-0.3.1.1 docopt-0.6.2 fastavro-0.21.24 fasteners-0.15 google-api-core-1.17.0 google-api-python-client-1.8.3 google-apitools-0.5.28 google-auth-oauthlib-0.4.1 google-cloud-bigtable-1.0.0 google-cloud-datastore-1.7.4 google-cloud-dlp-0.13.0 google-cloud-language-1.3.0 google-cloud-pubsub-1.0.2 google-cloud-spanner-1.13.0 google-cloud-videointelligence-1.13.0 google-cloud-vision-0.42.0 googledatastore-7.0.2 grpc-google-iam-v1-0.12.3 grpcio-gcp-0.2.2 hdfs-2.5.8 monotonic-1.5 oauth2client-3.0.0 proto-google-cloud-datastore-v1-0.90.4 pyarrow-0.16.0 python-dateutil-2.8.1 pyvcf-0.6.8 tensorflow-estimator-2.1.0 tensorflow-metadata-0.21.2 tensorflow-serving-api-2.1.0 tensorflow-transform-0.21.2 tfx-bsl-0.21.4 typing-extensions-3.7.4.2

# %% [markdown]
# ## Importing libraries

# %%
import tempfile
import pandas as pd
import tensorflow as tf
import tensorflow_transform as tft
import tensorflow_transform.beam.impl as tft_beam

import apache_beam.io.iobase #Adicionado novo import

from __future__ import print_function
from tensorflow_transform.tf_metadata import dataset_metadata, dataset_schema, schema_utils #Adicionado schema_utils

# %% [markdown]
# ## Preprocessing

# %% [markdown]
# ### Loading database

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
dataset = pd.read_csv("/content/drive/My Drive/Presentations/TensorFlow on Google Cloud/polution_small.csv")

# %%
dataset.head()
# Out:
#        Date   pm10    no2    so2   soot
# 0  1/1/2009  98.67  14.10  44.38  34.81
# 1  1/2/2009  52.33  14.10  29.75  33.06
# 2  1/3/2009  74.67  20.50  36.25  39.25
# 3  1/4/2009  72.00  17.30  46.44  34.38
# 4  1/5/2009  81.00  25.64  56.56  45.59

# %% [markdown]
# ### Droping column with datetime

# %%
features = dataset.drop("Date", axis = 1)

# %%
features.head()
# Out:
#     pm10    no2    so2   soot
# 0  98.67  14.10  44.38  34.81
# 1  52.33  14.10  29.75  33.06
# 2  74.67  20.50  36.25  39.25
# 3  72.00  17.30  46.44  34.38
# 4  81.00  25.64  56.56  45.59

# %% [markdown]
# ### Converting to a dictionary

# %%
dict_features = list(features.to_dict("index").values())

# %%
dict_features[0:2]
# Out:
# [{'no2': 14.1, 'pm10': 98.67, 'so2': 44.38, 'soot': 34.81},
#  {'no2': 14.1, 'pm10': 52.33, 'so2': 29.75, 'soot': 33.06}]

# %% [markdown]
# ### Defining metadata

# %%
data_metadata = dataset_metadata.DatasetMetadata(dataset_schema.from_feature_spec({
    "no2": tf.io.FixedLenFeature([], tf.float32),
    "pm10": tf.io.FixedLenFeature([], tf.float32),
    "so2": tf.io.FixedLenFeature([], tf.float32),
    "soot": tf.io.FixedLenFeature([], tf.float32),
}))
# Out:
# WARNING: Logging before flag parsing goes to stderr.
# W0519 18:41:16.057198 139799407392640 deprecation.py:323] From <ipython-input-11-e96c9b286142>:5: from_feature_spec (from tensorflow_transform.tf_metadata.dataset_schema) is deprecated and will be removed in a future version.
# Instructions for updating:
# from_feature_spec is a deprecated, use schema_utils.schema_from_feature_spec

# %%
data_metadata
# Out:
# {'_schema': feature {
#   name: "no2"
#   type: FLOAT
#   presence {
#     min_fraction: 1.0
#   }
#   shape {
#   }
# }
# feature {
#   name: "pm10"
#   type: FLOAT
#   presence {
#     min_fraction: 1.0
#   }
#   shape {
#   }
# }
# feature {
#   name: "so2"
#   type: FLOAT
#   presence {
#     min_fraction: 1.0
#   }
#   shape {
#   }
# }
# feature {
#   name: "soot"
#   type: FLOAT
#   presence {
#     min_fraction: 1.0
#   }
#   shape {
#   }
# }
# }

# %% [markdown]
# ## Preprocing function

# %%
def preprocessing_fn(inputs):
  no2 = inputs["no2"]
  pm10 = inputs["pm10"]
  so2 = inputs["so2"]
  soot = inputs["soot"]
  
  no2_normalized = no2 - tft.mean(no2)
  so2_normalized = so2 - tft.mean(so2)
  
  pm10_normalized = tft.scale_to_0_1(pm10)
  soot_normalized = tft.scale_by_min_max(soot)
  
  return {
      "no2_normalized": no2_normalized,
      "so2_normalized": so2_normalized,
      "pm10_normalized": pm10_normalized,
      "sott_normalized": soot_normalized
  }

# %% [markdown]
# ## Coding
#
# Tensorflow Transform use  **Apache Beam** background to perform operations.
#
# Function parameters:
#
#     dict_features - Our database converted to dict
#     data_metadata - Defined metadata
#     preprocessing_fn - preprocessing function
#
#
# Apache Beam Syntax
#
# ```
# result = data_to_pass | where_to_pass_the_data
# ```
#
# Explaining:
#
# **result**  -> `transformed_dataset, transform_fn`
#
# **data_to_pass** -> `(dict_features, data_metadata)`
#
# **where_to_pass_the_data** -> `tft_beam.AnalyzeAndTransformDataset(preprocessing_fn)`
#
# ```
# transformed_dataset, transform_fn = ((dict_features, data_metadata) | tft_beam.AnalyzeAndTransformDataset(preprocessing_fn))
#
# ```
#
# Learn more:
# https://beam.apache.org/documentation/programming-guide/#applying-transforms
#
# https://beam.apache.org/

# %%
def data_transform():
  with tft_beam.Context(temp_dir = tempfile.mkdtemp()):
    transformed_dataset, transform_fn = ((dict_features, data_metadata) | tft_beam.AnalyzeAndTransformDataset(preprocessing_fn))
    
  transformed_data, transformed_metadata = transformed_dataset
  
  for i in range(len(transformed_data)):
    print("Initial: ", dict_features[i])
    print("Transformed: ", transformed_data[i])

# %%
data_transform()
# Out:
# W0519 18:42:22.559719 139799407392640 impl.py:425] Tensorflow version (2.1.0) found. Note that Tensorflow Transform support for TF 2.0 is currently in beta, and features such as tf.function may not work as intended.
# W0519 18:42:22.574245 139799407392640 interactive_environment.py:112] Interactive Beam requires Python 3.5.3+.
# W0519 18:42:22.575671 139799407392640 interactive_environment.py:125] Dependencies required for Interactive Beam PCollection visualization are not available, please use: `pip install apache-beam[interactive]` to install necessary dependencies to enable all data visualization features.
# W0519 18:42:22.948338 139799407392640 impl.py:425] Tensorflow version (2.1.0) found. Note that Tensorflow Transform support for TF 2.0 is currently in beta, and features such as tf.function may not work as intended.
# W0519 18:42:24.590297 139799407392640 deprecation.py:323] From /usr/local/lib/python2.7/dist-packages/tensorflow_core/python/saved_model/signature_def_utils_impl.py:201: build_tensor_info (from tensorflow.python.saved_model.utils_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# This function will only be available through the v1 compatibility library as tf.compat.v1.saved_model.utils.build_tensor_info or tf.compat.v1.saved_model.build_tensor_info.
# W0519 18:42:24.600390 139799407392640 meta_graph.py:436] Issue encountered when serializing tft_analyzer_use.
# Type is unsupported, or the types of the items don't match field type in CollectionDef. Note this is a warning and probably safe to ignore.
# 'Counter' object has no attribute 'name'
# W0519 18:42:24.601831 139799407392640 meta_graph.py:436] Issue encountered when serializing tft_mapper_use.
# Type is unsupported, or the types of the items don't match field type in CollectionDef. Note this is a warning and probably safe to ignore.
# 'Counter' object has no attribute 'name'
# W0519 18:42:25.302077 139799407392640 meta_graph.py:436] Issue encountered when serializing tft_analyzer_use.
# Type is unsupported, or the types of the items don't match field type in CollectionDef. Note this is a warning and probably safe to ignore.
# 'Counter' object has no attribute 'name'
# W0519 18:42:25.303611 139799407392640 meta_graph.py:436] Issue encountered when serializing tft_mapper_use.
# Type is unsupported, or the types of the items don't match field type in CollectionDef. Note this is a warning and probably safe to ignore.
# 'Counter' object has no attribute 'name'
# W0519 18:42:25.413558 139799407392640 impl.py:425] Tensorflow version (2.1.0) found. Note that Tensorflow Transform support for TF 2.0 is currently in beta, and features such as tf.function may not work as intended.
# Initial:  {'so2': 44.38, 'no2': 14.1, 'pm10': 98.67, 'soot': 34.81}
# Transformed:  {u'no2_normalized': -18.577978, u'pm10_normalized': 0.34071696, u'so2_normalized': 28.855408, u'sott_normalized': 0.2834235}
# Initial:  {'so2': 29.75, 'no2': 14.1, 'pm10': 52.33, 'soot': 33.06}
# Transformed:  {u'no2_normalized': -18.577978, u'pm10_normalized': 0.16963857, u'so2_normalized': 14.225407, u'sott_normalized': 0.26620758}
# Initial:  {'so2': 36.25, 'no2': 20.5, 'pm10': 74.67, 'soot': 39.25}
# Transformed:  {u'no2_normalized': -12.1779785, u'pm10_normalized': 0.25211355, u'so2_normalized': 20.725407, u'sott_normalized': 0.32710278}
# Initial:  {'so2': 46.44, 'no2': 17.3, 'pm10': 72.0, 'soot': 34.38}
# Transformed:  {u'no2_normalized': -15.377979, u'pm10_normalized': 0.24225645, u'so2_normalized': 30.915405, u'sott_normalized': 0.2791933}
# Initial:  {'so2': 56.56, 'no2': 25.64, 'pm10': 81.0, 'soot': 45.59}
# Transformed:  {u'no2_normalized': -7.037979, u'pm10_normalized': 0.2754827, u'so2_normalized': 41.035408, u'sott_normalized': 0.38947365}
# Initial:  {'so2': 42.38, 'no2': 25.2, 'pm10': 147.0, 'soot': 69.33}
# Transformed:  {u'no2_normalized': -7.4779778, u'pm10_normalized': 0.51914203, u'so2_normalized': 26.855408, u'sott_normalized': 0.6230202}
# Initial:  {'so2': 71.69, 'no2': 21.91, 'pm10': 185.0, 'soot': 84.06}
# Transformed:  {u'no2_normalized': -10.767979, u'pm10_normalized': 0.6594307, u'so2_normalized': 56.16541, u'sott_normalized': 0.7679291}
# Initial:  {'so2': 51.75, 'no2': 25.09, 'pm10': 148.67, 'soot': 74.41}
# Transformed:  {u'no2_normalized': -7.5879784, u'pm10_normalized': 0.5253073, u'so2_normalized': 36.225407, u'sott_normalized': 0.67299557}
# Initial:  {'so2': 63.47, 'no2': 37.27, 'pm10': 216.0, 'soot': 64.06}
# Transformed:  {u'no2_normalized': 4.592022, u'pm10_normalized': 0.7738767, u'so2_normalized': 47.945408, u'sott_normalized': 0.5711755}
# Initial:  {'so2': 63.13, 'no2': 23.18, 'pm10': 135.67, 'soot': 58.94}
# Transformed:  {u'no2_normalized': -9.497978, u'pm10_normalized': 0.47731382, u'so2_normalized': 47.605408, u'sott_normalized': 0.52080667}
# Initial:  {'so2': 67.56, 'no2': 21.64, 'pm10': 138.67, 'soot': 49.65}
# Transformed:  {u'no2_normalized': -11.037979, u'pm10_normalized': 0.48838922, u'so2_normalized': 52.035404, u'sott_normalized': 0.42941466}
# Initial:  {'so2': 84.24, 'no2': 21.0, 'pm10': 96.67, 'soot': 49.83}
# Transformed:  {u'no2_normalized': -11.6779785, u'pm10_normalized': 0.33333334, u'so2_normalized': 68.71541, u'sott_normalized': 0.43118542}
# Initial:  {'so2': 83.06, 'no2': 22.64, 'pm10': 101.0, 'soot': 46.44}
# Transformed:  {u'no2_normalized': -10.037979, u'pm10_normalized': 0.34931886, u'so2_normalized': 67.5354, u'sott_normalized': 0.39783567}
# Initial:  {'so2': 78.11, 'no2': 25.42, 'pm10': 129.33, 'soot': 55.53}
# Transformed:  {u'no2_normalized': -7.2579784, u'pm10_normalized': 0.4539078, u'so2_normalized': 62.585407, u'sott_normalized': 0.48726016}
# Initial:  {'so2': 52.44, 'no2': 21.42, 'pm10': 101.0, 'soot': 42.42}
# Transformed:  {u'no2_normalized': -11.257978, u'pm10_normalized': 0.34931886, u'so2_normalized': 36.915405, u'sott_normalized': 0.3582882}
# Initial:  {'so2': 44.94, 'no2': 47.08, 'pm10': 83.67, 'soot': 39.84}
# Transformed:  {u'no2_normalized': 14.402023, u'pm10_normalized': 0.28533983, u'so2_normalized': 29.415405, u'sott_normalized': 0.33290702}
# Initial:  {'so2': 41.67, 'no2': 24.75, 'pm10': 88.67, 'soot': 47.79}
# Transformed:  {u'no2_normalized': -7.9279785, u'pm10_normalized': 0.30379888, u'so2_normalized': 26.145405, u'sott_normalized': 0.41111657}
# Initial:  {'so2': 87.22, 'no2': 34.75, 'pm10': 149.33, 'soot': 83.79}
# Transformed:  {u'no2_normalized': 2.0720215, u'pm10_normalized': 0.52774394, u'so2_normalized': 71.695404, u'sott_normalized': 0.765273}
# Initial:  {'so2': 52.89, 'no2': 32.08, 'pm10': 41.0, 'soot': 46.42}
# Transformed:  {u'no2_normalized': -0.5979767, u'pm10_normalized': 0.12781039, u'so2_normalized': 37.365406, u'sott_normalized': 0.39763892}
# Initial:  {'so2': 36.5, 'no2': 26.5, 'pm10': 46.33, 'soot': 27.76}
# Transformed:  {u'no2_normalized': -6.1779785, u'pm10_normalized': 0.14748773, u'so2_normalized': 20.975407, u'sott_normalized': 0.21406788}
# Initial:  {'so2': 28.59, 'no2': 19.67, 'pm10': 26.67, 'soot': 16.28}
# Transformed:  {u'no2_normalized': -13.007978, u'pm10_normalized': 0.07490678, u'so2_normalized': 13.065407, u'sott_normalized': 0.101131335}
# Initial:  {'so2': 19.82, 'no2': 23.42, 'pm10': 28.33, 'soot': 18.17}
# Transformed:  {u'no2_normalized': -9.257978, u'pm10_normalized': 0.08103518, u'so2_normalized': 4.2954063, u'sott_normalized': 0.11972454}
# Initial:  {'so2': 17.94, 'no2': 25.58, 'pm10': 40.67, 'soot': 28.56}
# Transformed:  {u'no2_normalized': -7.0979786, u'pm10_normalized': 0.12659208, u'so2_normalized': 2.4154072, u'sott_normalized': 0.221938}
# Initial:  {'so2': 19.88, 'no2': 30.33, 'pm10': 38.0, 'soot': 27.39}
# Transformed:  {u'no2_normalized': -2.3479786, u'pm10_normalized': 0.11673496, u'so2_normalized': 4.355406, u'sott_normalized': 0.21042792}
# Initial:  {'so2': 16.88, 'no2': 25.33, 'pm10': 25.0, 'soot': 16.17}
# Transformed:  {u'no2_normalized': -7.3479786, u'pm10_normalized': 0.068741456, u'so2_normalized': 1.3554058, u'sott_normalized': 0.10004918}
# Initial:  {'so2': 20.35, 'no2': 32.5, 'pm10': 48.67, 'soot': 29.11}
# Transformed:  {u'no2_normalized': -0.17797852, u'pm10_normalized': 0.15612654, u'so2_normalized': 4.825407, u'sott_normalized': 0.22734874}
# Initial:  {'so2': 25.47, 'no2': 27.42, 'pm10': 35.67, 'soot': 22.28}
# Transformed:  {u'no2_normalized': -5.2579784, u'pm10_normalized': 0.10813304, u'so2_normalized': 9.945406, u'sott_normalized': 0.1601574}
# Initial:  {'so2': 15.83, 'no2': 18.83, 'pm10': 21.33, 'soot': 19.88}
# Transformed:  {u'no2_normalized': -13.847979, u'pm10_normalized': 0.055192526, u'so2_normalized': 0.30540657, u'sott_normalized': 0.13654695}
# Initial:  {'so2': 14.44, 'no2': 17.5, 'pm10': 16.67, 'soot': 23.71}
# Transformed:  {u'no2_normalized': -15.1779785, u'pm10_normalized': 0.037988704, u'so2_normalized': -1.0845938, u'sott_normalized': 0.17422526}
# Initial:  {'so2': 15.28, 'no2': 15.42, 'pm10': 29.33, 'soot': 27.61}
# Transformed:  {u'no2_normalized': -17.257978, u'pm10_normalized': 0.084727, u'so2_normalized': -0.24459362, u'sott_normalized': 0.21259221}
# Initial:  {'so2': 17.39, 'no2': 17.0, 'pm10': 31.33, 'soot': 24.33}
# Transformed:  {u'no2_normalized': -15.6779785, u'pm10_normalized': 0.09211061, u'so2_normalized': 1.865406, u'sott_normalized': 0.18032463}
# Initial:  {'so2': 20.39, 'no2': 14.58, 'pm10': 25.67, 'soot': 23.0}
# Transformed:  {u'no2_normalized': -18.097979, u'pm10_normalized': 0.071214974, u'so2_normalized': 4.865406, u'sott_normalized': 0.16724052}
# Initial:  {'so2': 25.11, 'no2': 14.92, 'pm10': 21.33, 'soot': 19.78}
# Transformed:  {u'no2_normalized': -17.757978, u'pm10_normalized': 0.055192526, u'so2_normalized': 9.585407, u'sott_normalized': 0.13556321}
# Initial:  {'so2': 20.88, 'no2': 10.42, 'pm10': 19.67, 'soot': 19.79}
# Transformed:  {u'no2_normalized': -22.257978, u'pm10_normalized': 0.049064126, u'so2_normalized': 5.355406, u'sott_normalized': 0.13566159}
# Initial:  {'so2': 19.22, 'no2': 14.58, 'pm10': 49.67, 'soot': 29.84}
# Transformed:  {u'no2_normalized': -18.097979, u'pm10_normalized': 0.15981835, u'so2_normalized': 3.695406, u'sott_normalized': 0.23453024}
# Initial:  {'so2': 27.06, 'no2': 30.08, 'pm10': 62.0, 'soot': 48.0}
# Transformed:  {u'no2_normalized': -2.5979786, u'pm10_normalized': 0.20533834, u'so2_normalized': 11.535406, u'sott_normalized': 0.41318247}
# Initial:  {'so2': 21.61, 'no2': 27.67, 'pm10': 30.67, 'soot': 35.68}
# Transformed:  {u'no2_normalized': -5.0079784, u'pm10_normalized': 0.08967402, u'so2_normalized': 6.0854073, u'sott_normalized': 0.29198226}
# Initial:  {'so2': 16.39, 'no2': 19.58, 'pm10': 29.33, 'soot': 23.11}
# Transformed:  {u'no2_normalized': -13.097979, u'pm10_normalized': 0.084727, u'so2_normalized': 0.86540604, u'sott_normalized': 0.16832267}
# Initial:  {'so2': 15.11, 'no2': 16.17, 'pm10': 27.0, 'soot': 23.79}
# Transformed:  {u'no2_normalized': -16.507978, u'pm10_normalized': 0.07612507, u'so2_normalized': -0.4145937, u'sott_normalized': 0.17501229}
# Initial:  {'so2': 11.5, 'no2': 14.5, 'pm10': 12.67, 'soot': 15.94}
# Transformed:  {u'no2_normalized': -18.177979, u'pm10_normalized': 0.02322147, u'so2_normalized': -4.0245934, u'sott_normalized': 0.097786516}
# Initial:  {'so2': 17.67, 'no2': 25.0, 'pm10': 30.33, 'soot': 30.05}
# Transformed:  {u'no2_normalized': -7.6779785, u'pm10_normalized': 0.088418804, u'so2_normalized': 2.1454067, u'sott_normalized': 0.23659614}
# Initial:  {'so2': 15.56, 'no2': 21.0, 'pm10': 22.0, 'soot': 24.05}
# Transformed:  {u'no2_normalized': -11.6779785, u'pm10_normalized': 0.057666037, u'so2_normalized': 0.035407066, u'sott_normalized': 0.17757007}
# Initial:  {'so2': 14.33, 'no2': 17.82, 'pm10': 18.33, 'soot': 17.21}
# Transformed:  {u'no2_normalized': -14.857979, u'pm10_normalized': 0.044117104, u'so2_normalized': -1.1945934, u'sott_normalized': 0.11028036}
# Initial:  {'so2': 17.35, 'no2': 17.55, 'pm10': 21.33, 'soot': 17.83}
# Transformed:  {u'no2_normalized': -15.127979, u'pm10_normalized': 0.055192526, u'so2_normalized': 1.825407, u'sott_normalized': 0.11637972}
# Initial:  {'so2': 13.76, 'no2': 15.91, 'pm10': 24.0, 'soot': 16.94}
# Transformed:  {u'no2_normalized': -16.767979, u'pm10_normalized': 0.06504965, u'so2_normalized': -1.7645931, u'sott_normalized': 0.1076242}
# Initial:  {'so2': 13.35, 'no2': 12.91, 'pm10': 18.67, 'soot': 14.89}
# Transformed:  {u'no2_normalized': -19.767979, u'pm10_normalized': 0.04537232, u'so2_normalized': -2.174593, u'sott_normalized': 0.08745696}
# Initial:  {'so2': 16.35, 'no2': 23.18, 'pm10': 35.33, 'soot': 22.06}
# Transformed:  {u'no2_normalized': -9.497978, u'pm10_normalized': 0.10687784, u'so2_normalized': 0.825407, u'sott_normalized': 0.1579931}
# Initial:  {'so2': 21.65, 'no2': 32.27, 'pm10': 37.0, 'soot': 33.83}
# Transformed:  {u'no2_normalized': -0.40797806, u'pm10_normalized': 0.11304315, u'so2_normalized': 6.1254063, u'sott_normalized': 0.27378258}
# Initial:  {'so2': 16.28, 'no2': 19.33, 'pm10': 33.33, 'soot': 25.68}
# Transformed:  {u'no2_normalized': -13.347979, u'pm10_normalized': 0.09949423, u'so2_normalized': 0.75540733, u'sott_normalized': 0.1936055}
# Initial:  {'so2': 18.56, 'no2': 13.67, 'pm10': 20.0, 'soot': 19.53}
# Transformed:  {u'no2_normalized': -19.007978, u'pm10_normalized': 0.050282422, u'so2_normalized': 3.035406, u'sott_normalized': 0.13310379}
# Initial:  {'so2': 15.33, 'no2': 19.92, 'pm10': 34.33, 'soot': 21.89}
# Transformed:  {u'no2_normalized': -12.757978, u'pm10_normalized': 0.10318603, u'so2_normalized': -0.19459343, u'sott_normalized': 0.15632069}
# Initial:  {'so2': 17.33, 'no2': 23.0, 'pm10': 52.67, 'soot': 29.32}
# Transformed:  {u'no2_normalized': -9.6779785, u'pm10_normalized': 0.17089377, u'so2_normalized': 1.8054066, u'sott_normalized': 0.22941464}
# Initial:  {'so2': 13.78, 'no2': 23.17, 'pm10': 75.33, 'soot': 35.26}
# Transformed:  {u'no2_normalized': -9.507978, u'pm10_normalized': 0.25455016, u'so2_normalized': -1.7445936, u'sott_normalized': 0.28785044}
# Initial:  {'so2': 31.72, 'no2': 39.58, 'pm10': 114.33, 'soot': 53.37}
# Transformed:  {u'no2_normalized': 6.9020233, u'pm10_normalized': 0.39853066, u'so2_normalized': 16.195406, u'sott_normalized': 0.46601078}
# Initial:  {'so2': 35.06, 'no2': 39.08, 'pm10': 123.0, 'soot': 52.26}
# Transformed:  {u'no2_normalized': 6.4020233, u'pm10_normalized': 0.43053865, u'so2_normalized': 19.535408, u'sott_normalized': 0.45509094}
# Initial:  {'so2': 23.06, 'no2': 29.92, 'pm10': 89.0, 'soot': 39.63}
# Transformed:  {u'no2_normalized': -2.7579784, u'pm10_normalized': 0.30501717, u'so2_normalized': 7.535406, u'sott_normalized': 0.33084112}
# Initial:  {'so2': 23.72, 'no2': 31.0, 'pm10': 72.33, 'soot': 37.89}
# Transformed:  {u'no2_normalized': -1.6779785, u'pm10_normalized': 0.24347475, u'so2_normalized': 8.195406, u'sott_normalized': 0.31372353}
# Initial:  {'so2': 23.94, 'no2': 29.58, 'pm10': 44.33, 'soot': 35.47}
# Transformed:  {u'no2_normalized': -3.0979786, u'pm10_normalized': 0.14010412, u'so2_normalized': 8.415407, u'sott_normalized': 0.28991637}
# Initial:  {'so2': 20.72, 'no2': 31.5, 'pm10': 36.67, 'soot': 35.47}
# Transformed:  {u'no2_normalized': -1.1779785, u'pm10_normalized': 0.11182485, u'so2_normalized': 5.195406, u'sott_normalized': 0.28991637}
# Initial:  {'so2': 28.65, 'no2': 35.13, 'pm10': 75.5, 'soot': 48.47}
# Transformed:  {u'no2_normalized': 2.4520226, u'pm10_normalized': 0.25517777, u'so2_normalized': 13.125406, u'sott_normalized': 0.41780618}
# Initial:  {'so2': 26.5, 'no2': 30.25, 'pm10': 56.75, 'soot': 41.53}
# Transformed:  {u'no2_normalized': -2.4279785, u'pm10_normalized': 0.18595636, u'so2_normalized': 10.975407, u'sott_normalized': 0.34953266}
# Initial:  {'so2': 27.9, 'no2': 27.94, 'pm10': 56.5, 'soot': 43.32}
# Transformed:  {u'no2_normalized': -4.737978, u'pm10_normalized': 0.18503341, u'so2_normalized': 12.375406, u'sott_normalized': 0.36714214}
# Initial:  {'so2': 19.0, 'no2': 16.75, 'pm10': 38.5, 'soot': 26.11}
# Transformed:  {u'no2_normalized': -15.9279785, u'pm10_normalized': 0.11858086, u'so2_normalized': 3.4754066, u'sott_normalized': 0.1978357}
# Initial:  {'so2': 15.75, 'no2': 10.56, 'pm10': 22.75, 'soot': 21.11}
# Transformed:  {u'no2_normalized': -22.117977, u'pm10_normalized': 0.06043489, u'so2_normalized': 0.22540665, u'sott_normalized': 0.14864732}
# Initial:  {'so2': 15.8, 'no2': 17.81, 'pm10': 33.0, 'soot': 23.79}
# Transformed:  {u'no2_normalized': -14.867979, u'pm10_normalized': 0.09827592, u'so2_normalized': 0.27540684, u'sott_normalized': 0.17501229}
# Initial:  {'so2': 11.35, 'no2': 15.81, 'pm10': 29.83, 'soot': 18.21}
# Transformed:  {u'no2_normalized': -16.867977, u'pm10_normalized': 0.0865729, u'so2_normalized': -4.174593, u'sott_normalized': 0.12011804}
# Initial:  {'so2': 11.9, 'no2': 17.44, 'pm10': 31.17, 'soot': 22.32}
# Transformed:  {u'no2_normalized': -15.237978, u'pm10_normalized': 0.09151992, u'so2_normalized': -3.6245937, u'sott_normalized': 0.16055089}
# Initial:  {'so2': 17.1, 'no2': 22.81, 'pm10': 33.17, 'soot': 26.16}
# Transformed:  {u'no2_normalized': -9.867979, u'pm10_normalized': 0.09890352, u'so2_normalized': 1.575407, u'sott_normalized': 0.19832759}
# Initial:  {'so2': 14.5, 'no2': 20.75, 'pm10': 42.0, 'soot': 25.11}
# Transformed:  {u'no2_normalized': -11.9279785, u'pm10_normalized': 0.1315022, u'so2_normalized': -1.0245934, u'sott_normalized': 0.18799803}
# Initial:  {'so2': 17.85, 'no2': 22.13, 'pm10': 32.67, 'soot': 24.83}
# Transformed:  {u'no2_normalized': -10.547979, u'pm10_normalized': 0.09705762, u'so2_normalized': 2.325407, u'sott_normalized': 0.18524347}
# Initial:  {'so2': 14.25, 'no2': 17.44, 'pm10': 25.2, 'soot': 22.0}
# Transformed:  {u'no2_normalized': -15.237978, u'pm10_normalized': 0.06947982, u'so2_normalized': -1.2745934, u'sott_normalized': 0.15740284}
# Initial:  {'so2': 16.2, 'no2': 18.13, 'pm10': 25.67, 'soot': 20.22}
# Transformed:  {u'no2_normalized': -14.547979, u'pm10_normalized': 0.071214974, u'so2_normalized': 0.6754074, u'sott_normalized': 0.13989177}
# Initial:  {'so2': 14.0, 'no2': 18.06, 'pm10': 42.0, 'soot': 21.83}
# Transformed:  {u'no2_normalized': -14.617979, u'pm10_normalized': 0.1315022, u'so2_normalized': -1.5245934, u'sott_normalized': 0.15573044}
# Initial:  {'so2': 25.25, 'no2': 25.44, 'pm10': 72.0, 'soot': 35.72}
# Transformed:  {u'no2_normalized': -7.237978, u'pm10_normalized': 0.24225645, u'so2_normalized': 9.725407, u'sott_normalized': 0.2923758}
# Initial:  {'so2': 16.55, 'no2': 18.69, 'pm10': 38.83, 'soot': 20.33}
# Transformed:  {u'no2_normalized': -13.987978, u'pm10_normalized': 0.11979917, u'so2_normalized': 1.0254059, u'sott_normalized': 0.14097393}
# Initial:  {'so2': 13.65, 'no2': 17.19, 'pm10': 41.33, 'soot': 18.78}
# Transformed:  {u'no2_normalized': -15.487978, u'pm10_normalized': 0.1290287, u'so2_normalized': -1.8745937, u'sott_normalized': 0.12572552}
# Initial:  {'so2': 11.7, 'no2': 12.38, 'pm10': 23.17, 'soot': 16.06}
# Transformed:  {u'no2_normalized': -20.297977, u'pm10_normalized': 0.061985455, u'so2_normalized': -3.8245935, u'sott_normalized': 0.09896703}
# Initial:  {'so2': 12.3, 'no2': 16.63, 'pm10': 27.0, 'soot': 18.28}
# Transformed:  {u'no2_normalized': -16.04798, u'pm10_normalized': 0.07612507, u'so2_normalized': -3.2245932, u'sott_normalized': 0.12080669}
# Initial:  {'so2': 15.0, 'no2': 18.75, 'pm10': 38.33, 'soot': 19.05}
# Transformed:  {u'no2_normalized': -13.9279785, u'pm10_normalized': 0.11795326, u'so2_normalized': -0.52459335, u'sott_normalized': 0.12838168}
# Initial:  {'so2': 13.55, 'no2': 15.75, 'pm10': 26.6, 'soot': 15.74}
# Transformed:  {u'no2_normalized': -16.927979, u'pm10_normalized': 0.07464836, u'so2_normalized': -1.9745932, u'sott_normalized': 0.09581898}
# Initial:  {'so2': 12.4, 'no2': 14.94, 'pm10': 31.0, 'soot': 16.42}
# Transformed:  {u'no2_normalized': -17.73798, u'pm10_normalized': 0.09089231, u'so2_normalized': -3.1245937, u'sott_normalized': 0.102508605}
# Initial:  {'so2': 14.15, 'no2': 20.0, 'pm10': 28.0, 'soot': 17.79}
# Transformed:  {u'no2_normalized': -12.6779785, u'pm10_normalized': 0.079816885, u'so2_normalized': -1.3745937, u'sott_normalized': 0.11598623}
# Initial:  {'so2': 13.5, 'no2': 21.27, 'pm10': 21.83, 'soot': 14.59}
# Transformed:  {u'no2_normalized': -11.407978, u'pm10_normalized': 0.05703843, u'so2_normalized': -2.0245934, u'sott_normalized': 0.084505655}
# Initial:  {'so2': 12.6, 'no2': 18.57, 'pm10': 28.83, 'soot': 17.0}
# Transformed:  {u'no2_normalized': -14.107979, u'pm10_normalized': 0.082881086, u'so2_normalized': -2.924593, u'sott_normalized': 0.10821445}
# Initial:  {'so2': 17.4, 'no2': 26.33, 'pm10': 34.67, 'soot': 21.24}
# Transformed:  {u'no2_normalized': -6.3479786, u'pm10_normalized': 0.10444123, u'so2_normalized': 1.8754063, u'sott_normalized': 0.1499262}
# Initial:  {'so2': 17.95, 'no2': 28.0, 'pm10': 34.17, 'soot': 20.88}
# Transformed:  {u'no2_normalized': -4.6779785, u'pm10_normalized': 0.10259533, u'so2_normalized': 2.4254074, u'sott_normalized': 0.14638464}
# Initial:  {'so2': 14.85, 'no2': 22.6, 'pm10': 27.33, 'soot': 16.71}
# Transformed:  {u'no2_normalized': -10.077978, u'pm10_normalized': 0.077343374, u'so2_normalized': -0.674593, u'sott_normalized': 0.10536152}
# Initial:  {'so2': 10.95, 'no2': 13.29, 'pm10': 47.83, 'soot': 15.88}
# Transformed:  {u'no2_normalized': -19.387978, u'pm10_normalized': 0.15302543, u'so2_normalized': -4.5745935, u'sott_normalized': 0.09719626}
# Initial:  {'so2': 12.05, 'no2': 19.57, 'pm10': 29.83, 'soot': 16.82}
# Transformed:  {u'no2_normalized': -13.107979, u'pm10_normalized': 0.0865729, u'so2_normalized': -3.4745932, u'sott_normalized': 0.10644367}
# Initial:  {'so2': 9.9, 'no2': 19.21, 'pm10': 34.2, 'soot': 19.44}
# Transformed:  {u'no2_normalized': -13.467979, u'pm10_normalized': 0.1027061, u'so2_normalized': -5.6245937, u'sott_normalized': 0.13221839}
# Initial:  {'so2': 12.55, 'no2': 19.47, 'pm10': 60.83, 'soot': 24.65}
# Transformed:  {u'no2_normalized': -13.207979, u'pm10_normalized': 0.20101894, u'so2_normalized': -2.9745932, u'sott_normalized': 0.18347268}
# Initial:  {'so2': 10.95, 'no2': 17.46, 'pm10': 39.17, 'soot': 20.5}
# Transformed:  {u'no2_normalized': -15.217979, u'pm10_normalized': 0.121054366, u'so2_normalized': -4.5745935, u'sott_normalized': 0.14264633}
# Initial:  {'so2': 10.3, 'no2': 16.07, 'pm10': 27.5, 'soot': 16.27}
# Transformed:  {u'no2_normalized': -16.607979, u'pm10_normalized': 0.07797098, u'so2_normalized': -5.224593, u'sott_normalized': 0.10103296}
# Initial:  {'so2': 11.7, 'no2': 20.93, 'pm10': 35.33, 'soot': 21.27}
# Transformed:  {u'no2_normalized': -11.747978, u'pm10_normalized': 0.10687784, u'so2_normalized': -3.8245935, u'sott_normalized': 0.15022135}
# Initial:  {'so2': 12.45, 'no2': 31.07, 'pm10': 51.83, 'soot': 29.2}
# Transformed:  {u'no2_normalized': -1.6079788, u'pm10_normalized': 0.16779266, u'so2_normalized': -3.0745935, u'sott_normalized': 0.22823413}
# Initial:  {'so2': 14.1, 'no2': 29.0, 'pm10': 53.6, 'soot': 27.6}
# Transformed:  {u'no2_normalized': -3.6779785, u'pm10_normalized': 0.17432715, u'so2_normalized': -1.424593, u'sott_normalized': 0.21249384}
# Initial:  {'so2': 12.9, 'no2': 30.36, 'pm10': 48.0, 'soot': 27.63}
# Transformed:  {u'no2_normalized': -2.317978, u'pm10_normalized': 0.15365304, u'so2_normalized': -2.6245937, u'sott_normalized': 0.21278895}
# Initial:  {'so2': 11.25, 'no2': 30.8, 'pm10': 39.0, 'soot': 32.88}
# Transformed:  {u'no2_normalized': -1.8779793, u'pm10_normalized': 0.12042677, u'so2_normalized': -4.2745934, u'sott_normalized': 0.26443678}
# Initial:  {'so2': 14.15, 'no2': 34.33, 'pm10': 65.8, 'soot': 42.71}
# Transformed:  {u'no2_normalized': 1.6520233, u'pm10_normalized': 0.21936724, u'so2_normalized': -1.3745937, u'sott_normalized': 0.36114115}
# Initial:  {'so2': 19.2, 'no2': 38.6, 'pm10': 61.4, 'soot': 42.67}
# Transformed:  {u'no2_normalized': 5.92202, u'pm10_normalized': 0.20312327, u'so2_normalized': 3.6754074, u'sott_normalized': 0.36074764}
# Initial:  {'so2': 10.3, 'no2': 18.0, 'pm10': 39.17, 'soot': 18.61}
# Transformed:  {u'no2_normalized': -14.6779785, u'pm10_normalized': 0.121054366, u'so2_normalized': -5.224593, u'sott_normalized': 0.12405312}
# Initial:  {'so2': 9.8, 'no2': 15.27, 'pm10': 35.33, 'soot': 12.89}
# Transformed:  {u'no2_normalized': -17.407978, u'pm10_normalized': 0.10687784, u'so2_normalized': -5.724593, u'sott_normalized': 0.067781605}
# Initial:  {'so2': 8.8, 'no2': 15.36, 'pm10': 44.0, 'soot': 13.94}
# Transformed:  {u'no2_normalized': -17.317978, u'pm10_normalized': 0.13888581, u'so2_normalized': -6.724593, u'sott_normalized': 0.07811116}
# Initial:  {'so2': 11.6, 'no2': 22.57, 'pm10': 32.83, 'soot': 24.76}
# Transformed:  {u'no2_normalized': -10.107979, u'pm10_normalized': 0.09764832, u'so2_normalized': -3.924593, u'sott_normalized': 0.18455483}
# Initial:  {'so2': 12.3, 'no2': 25.5, 'pm10': 40.83, 'soot': 29.24}
# Transformed:  {u'no2_normalized': -7.1779785, u'pm10_normalized': 0.12718278, u'so2_normalized': -3.2245932, u'sott_normalized': 0.22862762}
# Initial:  {'so2': 14.7, 'no2': 39.69, 'pm10': 45.67, 'soot': 42.74}
# Transformed:  {u'no2_normalized': 7.01202, u'pm10_normalized': 0.14505112, u'so2_normalized': -0.82459354, u'sott_normalized': 0.3614363}
# Initial:  {'so2': 10.5, 'no2': 24.13, 'pm10': 27.67, 'soot': 17.84}
# Transformed:  {u'no2_normalized': -8.547979, u'pm10_normalized': 0.078598596, u'so2_normalized': -5.0245934, u'sott_normalized': 0.11647811}
# Initial:  {'so2': 9.45, 'no2': 22.94, 'pm10': 24.67, 'soot': 17.11}
# Transformed:  {u'no2_normalized': -9.737978, u'pm10_normalized': 0.06752317, u'so2_normalized': -6.0745935, u'sott_normalized': 0.109296605}
# Initial:  {'so2': 9.55, 'no2': 23.31, 'pm10': 34.0, 'soot': 23.05}
# Transformed:  {u'no2_normalized': -9.367979, u'pm10_normalized': 0.10196773, u'so2_normalized': -5.974593, u'sott_normalized': 0.1677324}
# Initial:  {'so2': 9.2, 'no2': 23.75, 'pm10': 28.17, 'soot': 19.68}
# Transformed:  {u'no2_normalized': -8.9279785, u'pm10_normalized': 0.0804445, u'so2_normalized': -6.3245935, u'sott_normalized': 0.13457943}
# Initial:  {'so2': 9.1, 'no2': 22.94, 'pm10': 34.33, 'soot': 19.05}
# Transformed:  {u'no2_normalized': -9.737978, u'pm10_normalized': 0.10318603, u'so2_normalized': -6.424593, u'sott_normalized': 0.12838168}
# Initial:  {'so2': 8.75, 'no2': 20.5, 'pm10': 29.67, 'soot': 18.89}
# Transformed:  {u'no2_normalized': -12.1779785, u'pm10_normalized': 0.08598221, u'so2_normalized': -6.7745934, u'sott_normalized': 0.12680766}
# Initial:  {'so2': 8.45, 'no2': 20.5, 'pm10': 19.75, 'soot': 17.05}
# Transformed:  {u'no2_normalized': -12.1779785, u'pm10_normalized': 0.04935947, u'so2_normalized': -7.0745935, u'sott_normalized': 0.10870633}
# Initial:  {'so2': 9.5, 'no2': 28.81, 'pm10': 28.83, 'soot': 28.32}
# Transformed:  {u'no2_normalized': -3.867979, u'pm10_normalized': 0.082881086, u'so2_normalized': -6.0245934, u'sott_normalized': 0.21957697}
# Initial:  {'so2': 11.3, 'no2': 28.13, 'pm10': 39.0, 'soot': 27.16}
# Transformed:  {u'no2_normalized': -4.5479794, u'pm10_normalized': 0.12042677, u'so2_normalized': -4.224593, u'sott_normalized': 0.20816526}
# Initial:  {'so2': 8.85, 'no2': 18.38, 'pm10': 24.5, 'soot': 13.47}
# Transformed:  {u'no2_normalized': -14.297979, u'pm10_normalized': 0.06689555, u'so2_normalized': -6.674593, u'sott_normalized': 0.07348745}
# Initial:  {'so2': 7.55, 'no2': 17.75, 'pm10': 23.33, 'soot': 14.42}
# Transformed:  {u'no2_normalized': -14.9279785, u'pm10_normalized': 0.062576145, u'so2_normalized': -7.974593, u'sott_normalized': 0.082833245}
# Initial:  {'so2': 9.55, 'no2': 19.38, 'pm10': 24.2, 'soot': 16.95}
# Transformed:  {u'no2_normalized': -13.297979, u'pm10_normalized': 0.065788016, u'so2_normalized': -5.974593, u'sott_normalized': 0.10772258}
# Initial:  {'so2': 9.05, 'no2': 23.93, 'pm10': 24.2, 'soot': 22.95}
# Transformed:  {u'no2_normalized': -8.747978, u'pm10_normalized': 0.065788016, u'so2_normalized': -6.474593, u'sott_normalized': 0.16674864}
# Initial:  {'so2': 8.85, 'no2': 21.2, 'pm10': 17.6, 'soot': 19.26}
# Transformed:  {u'no2_normalized': -11.477978, u'pm10_normalized': 0.041422084, u'so2_normalized': -6.674593, u'sott_normalized': 0.13044761}
# Initial:  {'so2': 7.9, 'no2': 15.5, 'pm10': 28.0, 'soot': 18.63}
# Transformed:  {u'no2_normalized': -17.177979, u'pm10_normalized': 0.079816885, u'so2_normalized': -7.6245933, u'sott_normalized': 0.12424986}
# Initial:  {'so2': 7.85, 'no2': 11.69, 'pm10': 25.67, 'soot': 16.68}
# Transformed:  {u'no2_normalized': -20.98798, u'pm10_normalized': 0.071214974, u'so2_normalized': -7.6745934, u'sott_normalized': 0.105066404}
# Initial:  {'so2': 9.3, 'no2': 19.94, 'pm10': 37.0, 'soot': 21.74}
# Transformed:  {u'no2_normalized': -12.737978, u'pm10_normalized': 0.11304315, u'so2_normalized': -6.224593, u'sott_normalized': 0.15484504}
# Initial:  {'so2': 10.1, 'no2': 22.75, 'pm10': 33.67, 'soot': 24.89}
# Transformed:  {u'no2_normalized': -9.9279785, u'pm10_normalized': 0.100749426, u'so2_normalized': -5.424593, u'sott_normalized': 0.18583372}
# Initial:  {'so2': 8.6, 'no2': 18.44, 'pm10': 25.17, 'soot': 20.05}
# Transformed:  {u'no2_normalized': -14.237978, u'pm10_normalized': 0.06936907, u'so2_normalized': -6.924593, u'sott_normalized': 0.13821937}
# Initial:  {'so2': 8.8, 'no2': 21.0, 'pm10': 22.0, 'soot': 21.05}
# Transformed:  {u'no2_normalized': -11.6779785, u'pm10_normalized': 0.057666037, u'so2_normalized': -6.724593, u'sott_normalized': 0.14805704}
# Initial:  {'so2': 8.5, 'no2': 21.75, 'pm10': 23.0, 'soot': 21.74}
# Transformed:  {u'no2_normalized': -10.9279785, u'pm10_normalized': 0.06135784, u'so2_normalized': -7.0245934, u'sott_normalized': 0.15484504}
# Initial:  {'so2': 10.85, 'no2': 29.63, 'pm10': 26.67, 'soot': 30.63}
# Transformed:  {u'no2_normalized': -3.0479794, u'pm10_normalized': 0.07490678, u'so2_normalized': -4.674593, u'sott_normalized': 0.242302}
# Initial:  {'so2': 13.4, 'no2': 33.25, 'pm10': 35.75, 'soot': 37.0}
# Transformed:  {u'no2_normalized': 0.5720215, u'pm10_normalized': 0.1084284, u'so2_normalized': -2.1245937, u'sott_normalized': 0.304968}
# Initial:  {'so2': 11.55, 'no2': 30.13, 'pm10': 31.0, 'soot': 30.42}
# Transformed:  {u'no2_normalized': -2.5479794, u'pm10_normalized': 0.09089231, u'so2_normalized': -3.9745932, u'sott_normalized': 0.24023609}
# Initial:  {'so2': 17.4, 'no2': 30.31, 'pm10': 36.5, 'soot': 27.63}
# Transformed:  {u'no2_normalized': -2.367979, u'pm10_normalized': 0.11119725, u'so2_normalized': 1.8754063, u'sott_normalized': 0.21278895}
# Initial:  {'so2': 10.65, 'no2': 26.13, 'pm10': 31.5, 'soot': 22.37}
# Transformed:  {u'no2_normalized': -6.5479794, u'pm10_normalized': 0.09273821, u'so2_normalized': -4.8745937, u'sott_normalized': 0.1610428}
# Initial:  {'so2': 9.1, 'no2': 17.25, 'pm10': 20.17, 'soot': 18.21}
# Transformed:  {u'no2_normalized': -15.4279785, u'pm10_normalized': 0.05091003, u'so2_normalized': -6.424593, u'sott_normalized': 0.12011804}
# Initial:  {'so2': 9.35, 'no2': 22.44, 'pm10': 32.5, 'soot': 22.95}
# Transformed:  {u'no2_normalized': -10.237978, u'pm10_normalized': 0.09643002, u'so2_normalized': -6.174593, u'sott_normalized': 0.16674864}
# Initial:  {'so2': 12.95, 'no2': 29.81, 'pm10': 47.67, 'soot': 28.84}
# Transformed:  {u'no2_normalized': -2.867979, u'pm10_normalized': 0.15243474, u'so2_normalized': -2.5745935, u'sott_normalized': 0.22469255}
# Initial:  {'so2': 13.3, 'no2': 28.81, 'pm10': 40.17, 'soot': 25.42}
# Transformed:  {u'no2_normalized': -3.867979, u'pm10_normalized': 0.12474617, u'so2_normalized': -2.2245932, u'sott_normalized': 0.1910477}
# Initial:  {'so2': 11.9, 'no2': 27.06, 'pm10': 44.17, 'soot': 25.37}
# Transformed:  {u'no2_normalized': -5.617979, u'pm10_normalized': 0.1395134, u'so2_normalized': -3.6245937, u'sott_normalized': 0.19055583}
# Initial:  {'so2': 11.8, 'no2': 25.19, 'pm10': 38.17, 'soot': 23.32}
# Transformed:  {u'no2_normalized': -7.487978, u'pm10_normalized': 0.11736256, u'so2_normalized': -3.7245932, u'sott_normalized': 0.17038858}
# Initial:  {'so2': 10.25, 'no2': 19.07, 'pm10': 34.17, 'soot': 21.11}
# Transformed:  {u'no2_normalized': -13.607979, u'pm10_normalized': 0.10259533, u'so2_normalized': -5.2745934, u'sott_normalized': 0.14864732}
# Initial:  {'so2': 9.45, 'no2': 16.4, 'pm10': 31.17, 'soot': 16.94}
# Transformed:  {u'no2_normalized': -16.277979, u'pm10_normalized': 0.09151992, u'so2_normalized': -6.0745935, u'sott_normalized': 0.1076242}
# Initial:  {'so2': 10.0, 'no2': 25.67, 'pm10': 35.67, 'soot': 20.78}
# Transformed:  {u'no2_normalized': -7.0079784, u'pm10_normalized': 0.10813304, u'so2_normalized': -5.5245934, u'sott_normalized': 0.14540088}
# Initial:  {'so2': 13.5, 'no2': 34.6, 'pm10': 43.17, 'soot': 27.78}
# Transformed:  {u'no2_normalized': 1.92202, u'pm10_normalized': 0.1358216, u'so2_normalized': -2.0245934, u'sott_normalized': 0.21426463}
# Initial:  {'so2': 9.75, 'no2': 23.27, 'pm10': 23.67, 'soot': 16.89}
# Transformed:  {u'no2_normalized': -9.407978, u'pm10_normalized': 0.06383136, u'so2_normalized': -5.7745934, u'sott_normalized': 0.1071323}
# Initial:  {'so2': 10.45, 'no2': 25.0, 'pm10': 29.5, 'soot': 23.72}
# Transformed:  {u'no2_normalized': -7.6779785, u'pm10_normalized': 0.0853546, u'so2_normalized': -5.0745935, u'sott_normalized': 0.17432365}
# Initial:  {'so2': 10.4, 'no2': 30.6, 'pm10': 39.17, 'soot': 25.89}
# Transformed:  {u'no2_normalized': -2.0779781, u'pm10_normalized': 0.121054366, u'so2_normalized': -5.1245937, u'sott_normalized': 0.19567141}
# Initial:  {'so2': 11.55, 'no2': 29.07, 'pm10': 35.0, 'soot': 22.16}
# Transformed:  {u'no2_normalized': -3.6079788, u'pm10_normalized': 0.10565954, u'so2_normalized': -3.9745932, u'sott_normalized': 0.15897687}
# Initial:  {'so2': 9.55, 'no2': 20.33, 'pm10': 28.0, 'soot': 17.42}
# Transformed:  {u'no2_normalized': -12.347979, u'pm10_normalized': 0.079816885, u'so2_normalized': -5.974593, u'sott_normalized': 0.11234628}
# Initial:  {'so2': 8.9, 'no2': 18.0, 'pm10': 20.5, 'soot': 16.33}
# Transformed:  {u'no2_normalized': -14.6779785, u'pm10_normalized': 0.052128326, u'so2_normalized': -6.6245937, u'sott_normalized': 0.10162321}
# Initial:  {'so2': 9.45, 'no2': 19.47, 'pm10': 21.17, 'soot': 17.11}
# Transformed:  {u'no2_normalized': -13.207979, u'pm10_normalized': 0.054601837, u'so2_normalized': -6.0745935, u'sott_normalized': 0.109296605}
# Initial:  {'so2': 9.7, 'no2': 17.67, 'pm10': 23.33, 'soot': 17.61}
# Transformed:  {u'no2_normalized': -15.007978, u'pm10_normalized': 0.062576145, u'so2_normalized': -5.8245935, u'sott_normalized': 0.11421544}
# Initial:  {'so2': 10.5, 'no2': 19.73, 'pm10': 28.33, 'soot': 17.67}
# Transformed:  {u'no2_normalized': -12.947979, u'pm10_normalized': 0.08103518, u'so2_normalized': -5.0245934, u'sott_normalized': 0.1148057}
# Initial:  {'so2': 9.1, 'no2': 22.33, 'pm10': 28.5, 'soot': 16.42}
# Transformed:  {u'no2_normalized': -10.347979, u'pm10_normalized': 0.08166279, u'so2_normalized': -6.424593, u'sott_normalized': 0.102508605}
# Initial:  {'so2': 9.15, 'no2': 23.25, 'pm10': 21.67, 'soot': 15.79}
# Transformed:  {u'no2_normalized': -9.4279785, u'pm10_normalized': 0.05644774, u'so2_normalized': -6.3745937, u'sott_normalized': 0.09631086}
# Initial:  {'so2': 9.7, 'no2': 23.87, 'pm10': 26.17, 'soot': 17.21}
# Transformed:  {u'no2_normalized': -8.807978, u'pm10_normalized': 0.07306088, u'so2_normalized': -5.8245935, u'sott_normalized': 0.11028036}
# Initial:  {'so2': 10.0, 'no2': 24.56, 'pm10': 25.67, 'soot': 20.21}
# Transformed:  {u'no2_normalized': -8.117979, u'pm10_normalized': 0.071214974, u'so2_normalized': -5.5245934, u'sott_normalized': 0.1397934}
# Initial:  {'so2': 9.35, 'no2': 26.5, 'pm10': 23.67, 'soot': 17.26}
# Transformed:  {u'no2_normalized': -6.1779785, u'pm10_normalized': 0.06383136, u'so2_normalized': -6.174593, u'sott_normalized': 0.11077225}
# Initial:  {'so2': 9.3, 'no2': 25.0, 'pm10': 24.17, 'soot': 20.42}
# Transformed:  {u'no2_normalized': -7.6779785, u'pm10_normalized': 0.06567726, u'so2_normalized': -6.224593, u'sott_normalized': 0.14185931}
# Initial:  {'so2': 9.75, 'no2': 24.5, 'pm10': 27.5, 'soot': 14.89}
# Transformed:  {u'no2_normalized': -8.1779785, u'pm10_normalized': 0.07797098, u'so2_normalized': -5.7745934, u'sott_normalized': 0.08745696}
# Initial:  {'so2': 9.85, 'no2': 25.27, 'pm10': 25.83, 'soot': 23.95}
# Transformed:  {u'no2_normalized': -7.407978, u'pm10_normalized': 0.07180566, u'so2_normalized': -5.674593, u'sott_normalized': 0.17658632}
# Initial:  {'so2': 11.9, 'no2': 29.94, 'pm10': 38.5, 'soot': 25.16}
# Transformed:  {u'no2_normalized': -2.737978, u'pm10_normalized': 0.11858086, u'so2_normalized': -3.6245937, u'sott_normalized': 0.1884899}
# Initial:  {'so2': 10.85, 'no2': 26.38, 'pm10': 31.83, 'soot': 20.79}
# Transformed:  {u'no2_normalized': -6.2979794, u'pm10_normalized': 0.093956515, u'so2_normalized': -4.674593, u'sott_normalized': 0.14549926}
# Initial:  {'so2': 9.6, 'no2': 20.69, 'pm10': 30.8, 'soot': 16.11}
# Transformed:  {u'no2_normalized': -11.987978, u'pm10_normalized': 0.09015394, u'so2_normalized': -5.924593, u'sott_normalized': 0.099458925}
# Initial:  {'so2': 9.95, 'no2': 21.69, 'pm10': 18.5, 'soot': 17.79}
# Transformed:  {u'no2_normalized': -10.987978, u'pm10_normalized': 0.04474471, u'so2_normalized': -5.5745935, u'sott_normalized': 0.11598623}
# Initial:  {'so2': 10.45, 'no2': 24.75, 'pm10': 24.5, 'soot': 20.32}
# Transformed:  {u'no2_normalized': -7.9279785, u'pm10_normalized': 0.06689555, u'so2_normalized': -5.0745935, u'sott_normalized': 0.14087555}
# Initial:  {'so2': 11.75, 'no2': 27.88, 'pm10': 23.67, 'soot': 22.53}
# Transformed:  {u'no2_normalized': -4.7979794, u'pm10_normalized': 0.06383136, u'so2_normalized': -3.7745934, u'sott_normalized': 0.16261682}
# Initial:  {'so2': 12.4, 'no2': 29.0, 'pm10': 25.67, 'soot': 20.89}
# Transformed:  {u'no2_normalized': -3.6779785, u'pm10_normalized': 0.071214974, u'so2_normalized': -3.1245937, u'sott_normalized': 0.14648302}
# Initial:  {'so2': 12.65, 'no2': 26.94, 'pm10': 25.5, 'soot': 21.11}
# Transformed:  {u'no2_normalized': -5.737978, u'pm10_normalized': 0.07058736, u'so2_normalized': -2.8745937, u'sott_normalized': 0.14864732}
# Initial:  {'so2': 10.75, 'no2': 23.5, 'pm10': 16.67, 'soot': 19.11}
# Transformed:  {u'no2_normalized': -9.1779785, u'pm10_normalized': 0.037988704, u'so2_normalized': -4.7745934, u'sott_normalized': 0.12897196}
# Initial:  {'so2': 12.7, 'no2': 28.31, 'pm10': 31.5, 'soot': 19.44}
# Transformed:  {u'no2_normalized': -4.367979, u'pm10_normalized': 0.09273821, u'so2_normalized': -2.8245935, u'sott_normalized': 0.13221839}
# Initial:  {'so2': 10.85, 'no2': 25.73, 'pm10': 31.67, 'soot': 19.65}
# Transformed:  {u'no2_normalized': -6.947979, u'pm10_normalized': 0.093365826, u'so2_normalized': -4.674593, u'sott_normalized': 0.1342843}
# Initial:  {'so2': 9.2, 'no2': 20.07, 'pm10': 26.67, 'soot': 18.0}
# Transformed:  {u'no2_normalized': -12.607979, u'pm10_normalized': 0.07490678, u'so2_normalized': -6.3245935, u'sott_normalized': 0.11805213}
# Initial:  {'so2': 9.65, 'no2': 19.87, 'pm10': 10.0, 'soot': 16.41}
# Transformed:  {u'no2_normalized': -12.807978, u'pm10_normalized': 0.013364344, u'so2_normalized': -5.8745937, u'sott_normalized': 0.10241023}
# Initial:  {'so2': 9.8, 'no2': 20.73, 'pm10': 11.83, 'soot': 18.56}
# Transformed:  {u'no2_normalized': -11.947979, u'pm10_normalized': 0.020120353, u'so2_normalized': -5.724593, u'sott_normalized': 0.123561226}
# Initial:  {'so2': 11.9, 'no2': 25.0, 'pm10': 23.67, 'soot': 17.67}
# Transformed:  {u'no2_normalized': -7.6779785, u'pm10_normalized': 0.06383136, u'so2_normalized': -3.6245937, u'sott_normalized': 0.1148057}
# Initial:  {'so2': 10.85, 'no2': 24.33, 'pm10': 20.33, 'soot': 16.72}
# Transformed:  {u'no2_normalized': -8.347979, u'pm10_normalized': 0.05150072, u'so2_normalized': -4.674593, u'sott_normalized': 0.1054599}
# Initial:  {'so2': 11.0, 'no2': 21.73, 'pm10': 18.67, 'soot': 13.61}
# Transformed:  {u'no2_normalized': -10.947979, u'pm10_normalized': 0.04537232, u'so2_normalized': -4.5245934, u'sott_normalized': 0.07486472}
# Initial:  {'so2': 11.5, 'no2': 22.87, 'pm10': 20.33, 'soot': 18.78}
# Transformed:  {u'no2_normalized': -9.807978, u'pm10_normalized': 0.05150072, u'so2_normalized': -4.0245934, u'sott_normalized': 0.12572552}
# Initial:  {'so2': 10.45, 'no2': 22.0, 'pm10': 32.5, 'soot': 20.0}
# Transformed:  {u'no2_normalized': -10.6779785, u'pm10_normalized': 0.09643002, u'so2_normalized': -5.0745935, u'sott_normalized': 0.13772748}
# Initial:  {'so2': 10.8, 'no2': 24.93, 'pm10': 33.25, 'soot': 22.56}
# Transformed:  {u'no2_normalized': -7.747978, u'pm10_normalized': 0.09919887, u'so2_normalized': -4.724593, u'sott_normalized': 0.16291194}
# Initial:  {'so2': 10.5, 'no2': 22.6, 'pm10': 26.5, 'soot': 19.11}
# Transformed:  {u'no2_normalized': -10.077978, u'pm10_normalized': 0.07427917, u'so2_normalized': -5.0245934, u'sott_normalized': 0.12897196}
# Initial:  {'so2': 10.3, 'no2': 26.6, 'pm10': 29.25, 'soot': 23.28}
# Transformed:  {u'no2_normalized': -6.077978, u'pm10_normalized': 0.08443164, u'so2_normalized': -5.224593, u'sott_normalized': 0.16999508}
# Initial:  {'so2': 10.28, 'no2': 25.69, 'pm10': 33.9, 'soot': 26.33}
# Transformed:  {u'no2_normalized': -6.987978, u'pm10_normalized': 0.10159855, u'so2_normalized': -5.2445936, u'sott_normalized': 0.19999999}
# Initial:  {'so2': 10.28, 'no2': 28.76, 'pm10': 40.03, 'soot': 29.17}
# Transformed:  {u'no2_normalized': -3.9179783, u'pm10_normalized': 0.12422933, u'so2_normalized': -5.2445936, u'sott_normalized': 0.227939}
# Initial:  {'so2': 10.72, 'no2': 28.01, 'pm10': 38.77, 'soot': 23.17}
# Transformed:  {u'no2_normalized': -4.6679783, u'pm10_normalized': 0.11957765, u'so2_normalized': -4.804593, u'sott_normalized': 0.16891293}
# Initial:  {'so2': 9.28, 'no2': 21.45, 'pm10': 33.68, 'soot': 19.89}
# Transformed:  {u'no2_normalized': -11.227978, u'pm10_normalized': 0.10078635, u'so2_normalized': -6.2445936, u'sott_normalized': 0.13664533}
# Initial:  {'so2': 9.35, 'no2': 18.79, 'pm10': 26.18, 'soot': 16.83}
# Transformed:  {u'no2_normalized': -13.887978, u'pm10_normalized': 0.073097795, u'so2_normalized': -6.174593, u'sott_normalized': 0.10654205}
# Initial:  {'so2': 9.67, 'no2': 28.15, 'pm10': 31.15, 'soot': 25.11}
# Transformed:  {u'no2_normalized': -4.527979, u'pm10_normalized': 0.09144608, u'so2_normalized': -5.8545933, u'sott_normalized': 0.18799803}
# Initial:  {'so2': 11.57, 'no2': 26.43, 'pm10': 32.42, 'soot': 23.28}
# Transformed:  {u'no2_normalized': -6.247978, u'pm10_normalized': 0.09613466, u'so2_normalized': -3.9545937, u'sott_normalized': 0.16999508}
# Initial:  {'so2': 9.83, 'no2': 23.91, 'pm10': 24.1, 'soot': 17.06}
# Transformed:  {u'no2_normalized': -8.767979, u'pm10_normalized': 0.06541884, u'so2_normalized': -5.6945934, u'sott_normalized': 0.10880471}
# Initial:  {'so2': 9.44, 'no2': 24.86, 'pm10': 21.87, 'soot': 25.06}
# Transformed:  {u'no2_normalized': -7.817978, u'pm10_normalized': 0.057186108, u'so2_normalized': -6.084594, u'sott_normalized': 0.18750612}
# Initial:  {'so2': 10.49, 'no2': 24.5, 'pm10': 25.8, 'soot': 19.95}
# Transformed:  {u'no2_normalized': -8.1779785, u'pm10_normalized': 0.0716949, u'so2_normalized': -5.0345936, u'sott_normalized': 0.13723561}
# Initial:  {'so2': 9.03, 'no2': 18.2, 'pm10': 15.02, 'soot': 13.16}
# Transformed:  {u'no2_normalized': -14.477978, u'pm10_normalized': 0.03189722, u'so2_normalized': -6.4945936, u'sott_normalized': 0.070437774}
# Initial:  {'so2': 9.07, 'no2': 17.79, 'pm10': 16.43, 'soot': 16.21}
# Transformed:  {u'no2_normalized': -14.887978, u'pm10_normalized': 0.03710267, u'so2_normalized': -6.4545937, u'sott_normalized': 0.10044268}
# Initial:  {'so2': 10.05, 'no2': 25.64, 'pm10': 23.88, 'soot': 21.84}
# Transformed:  {u'no2_normalized': -7.037979, u'pm10_normalized': 0.06460664, u'so2_normalized': -5.474593, u'sott_normalized': 0.15582882}
# Initial:  {'so2': 10.79, 'no2': 28.14, 'pm10': 32.32, 'soot': 23.05}
# Transformed:  {u'no2_normalized': -4.537979, u'pm10_normalized': 0.095765494, u'so2_normalized': -4.7345934, u'sott_normalized': 0.1677324}
# Initial:  {'so2': 12.89, 'no2': 27.55, 'pm10': 43.03, 'soot': 28.28}
# Transformed:  {u'no2_normalized': -5.1279793, u'pm10_normalized': 0.13530475, u'so2_normalized': -2.634593, u'sott_normalized': 0.21918346}
# Initial:  {'so2': 12.04, 'no2': 31.64, 'pm10': 45.87, 'soot': 23.56}
# Transformed:  {u'no2_normalized': -1.0379791, u'pm10_normalized': 0.14578949, u'so2_normalized': -3.4845934, u'sott_normalized': 0.17274961}
# Initial:  {'so2': 11.48, 'no2': 27.91, 'pm10': 40.35, 'soot': 19.67}
# Transformed:  {u'no2_normalized': -4.7679787, u'pm10_normalized': 0.1254107, u'so2_normalized': -4.044594, u'sott_normalized': 0.13448106}
# Initial:  {'so2': 10.99, 'no2': 21.54, 'pm10': 43.2, 'soot': 12.17}
# Transformed:  {u'no2_normalized': -11.137978, u'pm10_normalized': 0.13593237, u'so2_normalized': -4.5345936, u'sott_normalized': 0.060698472}
# Initial:  {'so2': 9.78, 'no2': 19.47, 'pm10': 30.17, 'soot': 12.44}
# Transformed:  {u'no2_normalized': -13.207979, u'pm10_normalized': 0.087828115, u'so2_normalized': -5.7445936, u'sott_normalized': 0.06335464}
# Initial:  {'so2': 10.55, 'no2': 24.83, 'pm10': 24.0, 'soot': 22.67}
# Transformed:  {u'no2_normalized': -7.8479786, u'pm10_normalized': 0.06504965, u'so2_normalized': -4.974593, u'sott_normalized': 0.16399409}
# Initial:  {'so2': 8.18, 'no2': 27.93, 'pm10': 28.35, 'soot': 22.72}
# Transformed:  {u'no2_normalized': -4.747978, u'pm10_normalized': 0.081109025, u'so2_normalized': -7.344593, u'sott_normalized': 0.16448596}
# Initial:  {'so2': 7.72, 'no2': 29.63, 'pm10': 25.25, 'soot': 22.33}
# Transformed:  {u'no2_normalized': -3.0479794, u'pm10_normalized': 0.06966441, u'so2_normalized': -7.8045936, u'sott_normalized': 0.16064927}
# Initial:  {'so2': 8.21, 'no2': 36.37, 'pm10': 33.55, 'soot': 29.5}
# Transformed:  {u'no2_normalized': 3.6920204, u'pm10_normalized': 0.100306414, u'so2_normalized': -7.3145933, u'sott_normalized': 0.23118542}
# Initial:  {'so2': 6.63, 'no2': 30.72, 'pm10': 33.93, 'soot': 24.5}
# Transformed:  {u'no2_normalized': -1.9579792, u'pm10_normalized': 0.101709306, u'so2_normalized': -8.894593, u'sott_normalized': 0.18199703}
# Initial:  {'so2': 7.87, 'no2': 25.5, 'pm10': 23.38, 'soot': 18.72}
# Transformed:  {u'no2_normalized': -7.1779785, u'pm10_normalized': 0.06276073, u'so2_normalized': -7.6545935, u'sott_normalized': 0.12513526}
# Initial:  {'so2': 7.1, 'no2': 18.33, 'pm10': 15.58, 'soot': 16.28}
# Transformed:  {u'no2_normalized': -14.347979, u'pm10_normalized': 0.03396463, u'so2_normalized': -8.424593, u'sott_normalized': 0.101131335}
# Initial:  {'so2': 7.62, 'no2': 28.78, 'pm10': 27.6, 'soot': 20.94}
# Transformed:  {u'no2_normalized': -3.8979778, u'pm10_normalized': 0.078340165, u'so2_normalized': -7.9045935, u'sott_normalized': 0.1469749}
# Initial:  {'so2': 7.66, 'no2': 31.81, 'pm10': 32.57, 'soot': 25.11}
# Transformed:  {u'no2_normalized': -0.86797905, u'pm10_normalized': 0.09668844, u'so2_normalized': -7.8645935, u'sott_normalized': 0.18799803}
# Initial:  {'so2': 8.18, 'no2': 32.51, 'pm10': 29.1, 'soot': 26.72}
# Transformed:  {u'no2_normalized': -0.1679802, u'pm10_normalized': 0.08387788, u'so2_normalized': -7.344593, u'sott_normalized': 0.20383668}
# Initial:  {'so2': 7.92, 'no2': 39.67, 'pm10': 31.2, 'soot': 28.94}
# Transformed:  {u'no2_normalized': 6.9920197, u'pm10_normalized': 0.09163067, u'so2_normalized': -7.6045933, u'sott_normalized': 0.22567633}
# Initial:  {'so2': 9.16, 'no2': 41.39, 'pm10': 29.78, 'soot': 27.59}
# Transformed:  {u'no2_normalized': 8.712021, u'pm10_normalized': 0.08638831, u'so2_normalized': -6.3645935, u'sott_normalized': 0.21239546}
# Initial:  {'so2': 6.11, 'no2': 33.29, 'pm10': 36.02, 'soot': 27.28}
# Transformed:  {u'no2_normalized': 0.6120224, u'pm10_normalized': 0.10942518, u'so2_normalized': -9.414593, u'sott_normalized': 0.20934579}
# Initial:  {'so2': 6.5, 'no2': 24.14, 'pm10': 40.15, 'soot': 19.61}
# Transformed:  {u'no2_normalized': -8.537979, u'pm10_normalized': 0.12467235, u'so2_normalized': -9.024593, u'sott_normalized': 0.1338908}
# Initial:  {'so2': 7.11, 'no2': 32.85, 'pm10': 33.95, 'soot': 23.53}
# Transformed:  {u'no2_normalized': 0.17201996, u'pm10_normalized': 0.10178314, u'so2_normalized': -8.414593, u'sott_normalized': 0.17245449}
# Initial:  {'so2': 6.49, 'no2': 35.14, 'pm10': 33.63, 'soot': 26.44}
# Transformed:  {u'no2_normalized': 2.4620209, u'pm10_normalized': 0.10060176, u'so2_normalized': -9.034594, u'sott_normalized': 0.20108214}
# Initial:  {'so2': 5.71, 'no2': 29.13, 'pm10': 18.25, 'soot': 21.0}
# Transformed:  {u'no2_normalized': -3.5479794, u'pm10_normalized': 0.04382176, u'so2_normalized': -9.814593, u'sott_normalized': 0.14756517}
# Initial:  {'so2': 5.39, 'no2': 26.85, 'pm10': 20.12, 'soot': 19.32}
# ...
# Transformed:  {u'no2_normalized': 17.812023, u'pm10_normalized': 0.25251967, u'so2_normalized': -1.844593, u'sott_normalized': 0.21977372}
# Initial:  {'so2': 14.17, 'no2': 52.83, 'pm10': 57.13, 'soot': 23.18}
# Transformed:  {u'no2_normalized': 20.152023, u'pm10_normalized': 0.18735924, u'so2_normalized': -1.3545933, u'sott_normalized': 0.16901131}
# Initial:  {'so2': 12.7, 'no2': 49.65, 'pm10': 53.88, 'soot': 21.81}
# Transformed:  {u'no2_normalized': 16.972023, u'pm10_normalized': 0.17536087, u'so2_normalized': -2.8245935, u'sott_normalized': 0.15553369}
# Initial:  {'so2': 12.58, 'no2': 37.85, 'pm10': 33.63, 'soot': 18.28}
# Transformed:  {u'no2_normalized': 5.17202, u'pm10_normalized': 0.10060176, u'so2_normalized': -2.9445934, u'sott_normalized': 0.12080669}
# Initial:  {'so2': 12.56, 'no2': 43.25, 'pm10': 40.23, 'soot': 20.93}
# Transformed:  {u'no2_normalized': 10.5720215, u'pm10_normalized': 0.12496769, u'so2_normalized': -2.964593, u'sott_normalized': 0.14687653}
# Initial:  {'so2': 12.31, 'no2': 39.97, 'pm10': 27.85, 'soot': 16.56}
# Transformed:  {u'no2_normalized': 7.2920227, u'pm10_normalized': 0.07926312, u'so2_normalized': -3.214593, u'sott_normalized': 0.103885874}
# Initial:  {'so2': 14.06, 'no2': 38.29, 'pm10': 41.93, 'soot': 17.41}
# Transformed:  {u'no2_normalized': 5.6120224, u'pm10_normalized': 0.13124377, u'so2_normalized': -1.4645929, u'sott_normalized': 0.1122479}
# Initial:  {'so2': 15.48, 'no2': 48.91, 'pm10': 47.85, 'soot': 22.3}
# Transformed:  {u'no2_normalized': 16.232021, u'pm10_normalized': 0.15309927, u'so2_normalized': -0.04459381, u'sott_normalized': 0.16035414}
# Initial:  {'so2': 15.39, 'no2': 53.99, 'pm10': 54.2, 'soot': 19.85}
# Transformed:  {u'no2_normalized': 21.312023, u'pm10_normalized': 0.17654225, u'so2_normalized': -0.13459301, u'sott_normalized': 0.13625184}
# Initial:  {'so2': 10.09, 'no2': 36.62, 'pm10': 25.95, 'soot': 13.38}
# Transformed:  {u'no2_normalized': 3.9420204, u'pm10_normalized': 0.072248675, u'so2_normalized': -5.434593, u'sott_normalized': 0.07260206}
# Initial:  {'so2': 10.04, 'no2': 33.32, 'pm10': 21.2, 'soot': 14.46}
# Transformed:  {u'no2_normalized': 0.6420212, u'pm10_normalized': 0.054712594, u'so2_normalized': -5.4845934, u'sott_normalized': 0.083226755}
# Initial:  {'so2': 15.39, 'no2': 35.54, 'pm10': 25.2, 'soot': 14.41}
# Transformed:  {u'no2_normalized': 2.8620224, u'pm10_normalized': 0.06947982, u'so2_normalized': -0.13459301, u'sott_normalized': 0.08273487}
# Initial:  {'so2': 14.31, 'no2': 30.34, 'pm10': 21.73, 'soot': 15.31}
# Transformed:  {u'no2_normalized': -2.3379784, u'pm10_normalized': 0.05666925, u'so2_normalized': -1.2145929, u'sott_normalized': 0.09158878}
# Initial:  {'so2': 11.03, 'no2': 29.7, 'pm10': 19.0, 'soot': 13.63}
# Transformed:  {u'no2_normalized': -2.9779778, u'pm10_normalized': 0.046590615, u'so2_normalized': -4.4945936, u'sott_normalized': 0.075061485}
# Initial:  {'so2': 15.98, 'no2': 37.31, 'pm10': 38.15, 'soot': 17.72}
# Transformed:  {u'no2_normalized': 4.632023, u'pm10_normalized': 0.11728874, u'so2_normalized': 0.4554062, u'sott_normalized': 0.11529758}
# Initial:  {'so2': 18.52, 'no2': 39.72, 'pm10': 44.1, 'soot': 16.19}
# Transformed:  {u'no2_normalized': 7.0420227, u'pm10_normalized': 0.13925499, u'so2_normalized': 2.995407, u'sott_normalized': 0.10024594}
# Initial:  {'so2': 15.38, 'no2': 34.53, 'pm10': 48.13, 'soot': 17.83}
# Transformed:  {u'no2_normalized': 1.8520203, u'pm10_normalized': 0.15413298, u'so2_normalized': -0.14459324, u'sott_normalized': 0.11637972}
# Initial:  {'so2': 15.05, 'no2': 35.09, 'pm10': 80.6, 'soot': 21.1}
# Transformed:  {u'no2_normalized': 2.4120216, u'pm10_normalized': 0.27400598, u'so2_normalized': -0.47459316, u'sott_normalized': 0.14854893}
# Initial:  {'so2': 18.59, 'no2': 48.86, 'pm10': 76.83, 'soot': 22.71}
# Transformed:  {u'no2_normalized': 16.182022, u'pm10_normalized': 0.26008788, u'so2_normalized': 3.0654068, u'sott_normalized': 0.16438758}
# Initial:  {'so2': 18.2, 'no2': 50.83, 'pm10': 63.58, 'soot': 20.75}
# Transformed:  {u'no2_normalized': 18.152023, u'pm10_normalized': 0.21117142, u'so2_normalized': 2.6754074, u'sott_normalized': 0.14510575}
# Initial:  {'so2': 17.4, 'no2': 49.24, 'pm10': 76.58, 'soot': 24.63}
# Transformed:  {u'no2_normalized': 16.562023, u'pm10_normalized': 0.25916493, u'so2_normalized': 1.8754063, u'sott_normalized': 0.18327592}
# Initial:  {'so2': 16.24, 'no2': 33.23, 'pm10': 48.1, 'soot': 20.34}
# Transformed:  {u'no2_normalized': 0.552021, u'pm10_normalized': 0.15402222, u'so2_normalized': 0.7154064, u'sott_normalized': 0.1410723}
# Initial:  {'so2': 12.81, 'no2': 42.15, 'pm10': 41.7, 'soot': 19.26}
# Transformed:  {u'no2_normalized': 9.472023, u'pm10_normalized': 0.13039465, u'so2_normalized': -2.714593, u'sott_normalized': 0.13044761}
# Initial:  {'so2': 10.92, 'no2': 33.64, 'pm10': 39.53, 'soot': 16.76}
# Transformed:  {u'no2_normalized': 0.9620209, u'pm10_normalized': 0.12238342, u'so2_normalized': -4.6045933, u'sott_normalized': 0.105853416}
# Initial:  {'so2': 7.78, 'no2': 31.27, 'pm10': 43.15, 'soot': 16.78}
# Transformed:  {u'no2_normalized': -1.407978, u'pm10_normalized': 0.13574778, u'so2_normalized': -7.744593, u'sott_normalized': 0.10605017}
# Initial:  {'so2': 9.93, 'no2': 35.07, 'pm10': 37.75, 'soot': 16.31}
# Transformed:  {u'no2_normalized': 2.3920212, u'pm10_normalized': 0.11581201, u'so2_normalized': -5.594593, u'sott_normalized': 0.10142645}
# Initial:  {'so2': 10.1, 'no2': 35.01, 'pm10': 48.85, 'soot': 13.81}
# Transformed:  {u'no2_normalized': 2.3320198, u'pm10_normalized': 0.15679108, u'so2_normalized': -5.424593, u'sott_normalized': 0.076832265}
# Initial:  {'so2': 11.7, 'no2': 42.74, 'pm10': 49.2, 'soot': 15.83}
# Transformed:  {u'no2_normalized': 10.062023, u'pm10_normalized': 0.15808322, u'so2_normalized': -3.8245935, u'sott_normalized': 0.09670437}
# Initial:  {'so2': 12.48, 'no2': 44.01, 'pm10': 49.65, 'soot': 18.78}
# Transformed:  {u'no2_normalized': 11.33202, u'pm10_normalized': 0.15974453, u'so2_normalized': -3.0445938, u'sott_normalized': 0.12572552}
# Initial:  {'so2': 10.33, 'no2': 33.62, 'pm10': 35.98, 'soot': 17.32}
# Transformed:  {u'no2_normalized': 0.9420204, u'pm10_normalized': 0.10927751, u'so2_normalized': -5.1945934, u'sott_normalized': 0.11136251}
# Initial:  {'so2': 12.98, 'no2': 27.43, 'pm10': 31.35, 'soot': 16.06}
# Transformed:  {u'no2_normalized': -5.247978, u'pm10_normalized': 0.09218445, u'so2_normalized': -2.5445938, u'sott_normalized': 0.09896703}
# Initial:  {'so2': 10.92, 'no2': 28.23, 'pm10': 37.8, 'soot': 13.54}
# Transformed:  {u'no2_normalized': -4.447979, u'pm10_normalized': 0.1159966, u'so2_normalized': -4.6045933, u'sott_normalized': 0.07417609}
# Initial:  {'so2': 11.08, 'no2': 34.86, 'pm10': 32.88, 'soot': 10.47}
# Transformed:  {u'no2_normalized': 2.182022, u'pm10_normalized': 0.09783291, u'so2_normalized': -4.4445934, u'sott_normalized': 0.043974422}
# Initial:  {'so2': 9.95, 'no2': 27.07, 'pm10': 30.68, 'soot': 11.03}
# Transformed:  {u'no2_normalized': -5.607979, u'pm10_normalized': 0.08971093, u'so2_normalized': -5.5745935, u'sott_normalized': 0.049483515}
# Initial:  {'so2': 12.35, 'no2': 23.1, 'pm10': 27.85, 'soot': 11.38}
# Transformed:  {u'no2_normalized': -9.577978, u'pm10_normalized': 0.07926312, u'so2_normalized': -3.174593, u'sott_normalized': 0.052926708}
# Initial:  {'so2': 12.55, 'no2': 27.42, 'pm10': 32.95, 'soot': 11.92}
# Transformed:  {u'no2_normalized': -5.2579784, u'pm10_normalized': 0.098091334, u'so2_normalized': -2.9745932, u'sott_normalized': 0.058239054}
# Initial:  {'so2': 12.02, 'no2': 30.36, 'pm10': 22.08, 'soot': 10.5}
# Transformed:  {u'no2_normalized': -2.317978, u'pm10_normalized': 0.057961382, u'so2_normalized': -3.504593, u'sott_normalized': 0.04426955}
# Initial:  {'so2': 14.79, 'no2': 35.57, 'pm10': 32.73, 'soot': 12.7}
# Transformed:  {u'no2_normalized': 2.8920212, u'pm10_normalized': 0.09727913, u'so2_normalized': -0.7345934, u'sott_normalized': 0.06591244}
# Initial:  {'so2': 14.07, 'no2': 30.92, 'pm10': 28.98, 'soot': 13.15}
# Transformed:  {u'no2_normalized': -1.7579784, u'pm10_normalized': 0.08343485, u'so2_normalized': -1.4545937, u'sott_normalized': 0.07033939}
# Initial:  {'so2': 15.36, 'no2': 34.51, 'pm10': 42.05, 'soot': 13.18}
# Transformed:  {u'no2_normalized': 1.8320198, u'pm10_normalized': 0.13168678, u'so2_normalized': -0.1645937, u'sott_normalized': 0.07063453}
# Initial:  {'so2': 14.98, 'no2': 45.75, 'pm10': 58.78, 'soot': 22.3}
# Transformed:  {u'no2_normalized': 13.0720215, u'pm10_normalized': 0.19345072, u'so2_normalized': -0.5445938, u'sott_normalized': 0.16035414}
# Initial:  {'so2': 15.23, 'no2': 51.06, 'pm10': 63.48, 'soot': 25.33}
# Transformed:  {u'no2_normalized': 18.382023, u'pm10_normalized': 0.21080223, u'so2_normalized': -0.2945938, u'sott_normalized': 0.19016232}
# Initial:  {'so2': 15.44, 'no2': 42.83, 'pm10': 57.1, 'soot': 27.76}
# Transformed:  {u'no2_normalized': 10.152023, u'pm10_normalized': 0.18724848, u'so2_normalized': -0.08459377, u'sott_normalized': 0.21406788}
# Initial:  {'so2': 13.78, 'no2': 38.46, 'pm10': 34.05, 'soot': 19.68}
# Transformed:  {u'no2_normalized': 5.7820206, u'pm10_normalized': 0.10215232, u'so2_normalized': -1.7445936, u'sott_normalized': 0.13457943}
# Initial:  {'so2': 13.79, 'no2': 40.8, 'pm10': 36.8, 'soot': 18.8}
# Transformed:  {u'no2_normalized': 8.122021, u'pm10_normalized': 0.11230479, u'so2_normalized': -1.7345934, u'sott_normalized': 0.12592226}
# Initial:  {'so2': 12.44, 'no2': 34.6, 'pm10': 35.15, 'soot': 18.1}
# Transformed:  {u'no2_normalized': 1.92202, u'pm10_normalized': 0.10621332, u'so2_normalized': -3.0845938, u'sott_normalized': 0.11903591}
# Initial:  {'so2': 16.46, 'no2': 39.76, 'pm10': 49.28, 'soot': 18.62}
# Transformed:  {u'no2_normalized': 7.08202, u'pm10_normalized': 0.15837854, u'so2_normalized': 0.93540573, u'sott_normalized': 0.1241515}
# Initial:  {'so2': 15.99, 'no2': 38.92, 'pm10': 66.23, 'soot': 24.0}
# Transformed:  {u'no2_normalized': 6.2420197, u'pm10_normalized': 0.2209547, u'so2_normalized': 0.46540642, u'sott_normalized': 0.1770782}
# Initial:  {'so2': 12.58, 'no2': 29.95, 'pm10': 51.9, 'soot': 17.11}
# Transformed:  {u'no2_normalized': -2.7279778, u'pm10_normalized': 0.1680511, u'so2_normalized': -2.9445934, u'sott_normalized': 0.109296605}
# Initial:  {'so2': 16.75, 'no2': 20.78, 'pm10': 41.4, 'soot': 16.29}
# Transformed:  {u'no2_normalized': -11.897978, u'pm10_normalized': 0.12928711, u'so2_normalized': 1.2254066, u'sott_normalized': 0.10122971}
# Initial:  {'so2': 15.29, 'no2': 26.44, 'pm10': 26.83, 'soot': 11.27}
# Transformed:  {u'no2_normalized': -6.237978, u'pm10_normalized': 0.07549747, u'so2_normalized': -0.23459339, u'sott_normalized': 0.051844567}
# Initial:  {'so2': 16.08, 'no2': 26.38, 'pm10': 22.47, 'soot': 8.19}
# Transformed:  {u'no2_normalized': -6.2979794, u'pm10_normalized': 0.059401188, u'so2_normalized': 0.5554066, u'sott_normalized': 0.02154451}
# Initial:  {'so2': 16.79, 'no2': 27.9, 'pm10': 17.87, 'soot': 9.55}
# Transformed:  {u'no2_normalized': -4.777979, u'pm10_normalized': 0.042418875, u'so2_normalized': 1.2654076, u'sott_normalized': 0.03492376}
# Initial:  {'so2': 18.79, 'no2': 27.23, 'pm10': 21.73, 'soot': 8.49}
# Transformed:  {u'no2_normalized': -5.447979, u'pm10_normalized': 0.05666925, u'so2_normalized': 3.2654076, u'sott_normalized': 0.024495816}
# Initial:  {'so2': 14.36, 'no2': 27.29, 'pm10': 22.07, 'soot': 11.04}
# Transformed:  {u'no2_normalized': -5.3879776, u'pm10_normalized': 0.057924464, u'so2_normalized': -1.1645937, u'sott_normalized': 0.049581897}
# Initial:  {'so2': 15.87, 'no2': 34.32, 'pm10': 53.3, 'soot': 12.51}
# Transformed:  {u'no2_normalized': 1.6420212, u'pm10_normalized': 0.17321962, u'so2_normalized': 0.34540653, u'sott_normalized': 0.06404328}
# Initial:  {'so2': 19.79, 'no2': 32.79, 'pm10': 72.27, 'soot': 14.8}
# Transformed:  {u'no2_normalized': 0.1120224, u'pm10_normalized': 0.24325322, u'so2_normalized': 4.2654076, u'sott_normalized': 0.08657157}
# Initial:  {'so2': 15.19, 'no2': 25.75, 'pm10': 35.07, 'soot': 12.5}
# Transformed:  {u'no2_normalized': -6.9279785, u'pm10_normalized': 0.10591796, u'so2_normalized': -0.33459377, u'sott_normalized': 0.063944906}
# Initial:  {'so2': 14.51, 'no2': 33.26, 'pm10': 30.7, 'soot': 14.18}
# Transformed:  {u'no2_normalized': 0.5820198, u'pm10_normalized': 0.089784764, u'so2_normalized': -1.0145931, u'sott_normalized': 0.08047221}
# Initial:  {'so2': 27.18, 'no2': 37.4, 'pm10': 59.2, 'soot': 20.77}
# Transformed:  {u'no2_normalized': 4.722023, u'pm10_normalized': 0.19500129, u'so2_normalized': 11.655407, u'sott_normalized': 0.1453025}
# Initial:  {'so2': 23.2, 'no2': 47.61, 'pm10': 89.33, 'soot': 25.04}
# Transformed:  {u'no2_normalized': 14.932022, u'pm10_normalized': 0.3062355, u'so2_normalized': 7.6754074, u'sott_normalized': 0.1873094}
# Initial:  {'so2': 21.38, 'no2': 55.61, 'pm10': 78.7, 'soot': 27.87}
# Transformed:  {u'no2_normalized': 22.932022, u'pm10_normalized': 0.26699156, u'so2_normalized': 5.855406, u'sott_normalized': 0.21515001}
# Initial:  {'so2': 23.24, 'no2': 85.79, 'pm10': 177.1, 'soot': 36.75}
# Transformed:  {u'no2_normalized': 53.112022, u'pm10_normalized': 0.6302654, u'so2_normalized': 7.7154064, u'sott_normalized': 0.3025086}
# Initial:  {'so2': 25.1, 'no2': 89.32, 'pm10': 190.23, 'soot': 34.97}
# Transformed:  {u'no2_normalized': 56.64202, u'pm10_normalized': 0.67873883, u'so2_normalized': 9.575407, u'sott_normalized': 0.28499752}
# Initial:  {'so2': 21.36, 'no2': 58.59, 'pm10': 142.83, 'soot': 23.35}
# Transformed:  {u'no2_normalized': 25.912022, u'pm10_normalized': 0.50374717, u'so2_normalized': 5.8354073, u'sott_normalized': 0.17068371}
# Initial:  {'so2': 19.86, 'no2': 42.78, 'pm10': 88.77, 'soot': 23.85}
# Transformed:  {u'no2_normalized': 10.10202, u'pm10_normalized': 0.30416805, u'so2_normalized': 4.3354073, u'sott_normalized': 0.17560256}
# Initial:  {'so2': 19.28, 'no2': 52.96, 'pm10': 63.73, 'soot': 26.09}
# Transformed:  {u'no2_normalized': 20.28202, u'pm10_normalized': 0.21172518, u'so2_normalized': 3.7554073, u'sott_normalized': 0.19763894}
# Initial:  {'so2': 25.87, 'no2': 82.11, 'pm10': 114.83, 'soot': 29.71}
# Transformed:  {u'no2_normalized': 49.432022, u'pm10_normalized': 0.4003766, u'so2_normalized': 10.3454075, u'sott_normalized': 0.23325133}
# Initial:  {'so2': 20.27, 'no2': 61.62, 'pm10': 75.4, 'soot': 24.95}
# Transformed:  {u'no2_normalized': 28.94202, u'pm10_normalized': 0.2548086, u'so2_normalized': 4.745407, u'sott_normalized': 0.186424}
# Initial:  {'so2': 19.6, 'no2': 39.94, 'pm10': 67.47, 'soot': 19.67}
# Transformed:  {u'no2_normalized': 7.26202, u'pm10_normalized': 0.22553255, u'so2_normalized': 4.075407, u'sott_normalized': 0.13448106}
# Initial:  {'so2': 25.36, 'no2': 71.05, 'pm10': 62.93, 'soot': 19.86}
# Transformed:  {u'no2_normalized': 38.372025, u'pm10_normalized': 0.20877174, u'so2_normalized': 9.835407, u'sott_normalized': 0.13635021}
# Initial:  {'so2': 30.76, 'no2': 86.51, 'pm10': 114.03, 'soot': 29.9}
# Transformed:  {u'no2_normalized': 53.832024, u'pm10_normalized': 0.39742312, u'so2_normalized': 15.235407, u'sott_normalized': 0.23512049}
# Initial:  {'so2': 33.76, 'no2': 106.03, 'pm10': 178.07, 'soot': 43.22}
# Transformed:  {u'no2_normalized': 73.35202, u'pm10_normalized': 0.6338465, u'so2_normalized': 18.235405, u'sott_normalized': 0.36615837}
# Initial:  {'so2': 27.73, 'no2': 82.28, 'pm10': 98.0, 'soot': 31.5}
# Transformed:  {u'no2_normalized': 49.60202, u'pm10_normalized': 0.33824345, u'so2_normalized': 12.205406, u'sott_normalized': 0.25086078}
# Initial:  {'so2': 15.76, 'no2': 44.24, 'pm10': 24.07, 'soot': 16.46}
# Transformed:  {u'no2_normalized': 11.562023, u'pm10_normalized': 0.06530808, u'so2_normalized': 0.23540688, u'sott_normalized': 0.1029021}
# Initial:  {'so2': 18.57, 'no2': 42.27, 'pm10': 24.03, 'soot': 14.21}
# Transformed:  {u'no2_normalized': 9.592022, u'pm10_normalized': 0.065160416, u'so2_normalized': 3.0454063, u'sott_normalized': 0.08076733}
# Initial:  {'so2': 15.66, 'no2': 31.57, 'pm10': 47.97, 'soot': 14.01}
# Transformed:  {u'no2_normalized': -1.1079788, u'pm10_normalized': 0.1535423, u'so2_normalized': 0.1354065, u'sott_normalized': 0.0787998}

# %% [markdown]
# https://www.tensorflow.org/tfx/transform/get_started
